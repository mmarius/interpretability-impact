# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))

# %%
from utils import *

import pandas as pd
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
df = pd.read_csv('../data/emnlp2018/papers.csv')
df
# Out:
#                                                  Track Submission ID  \
# 0    Area A (Information Extraction and Question An...      587-TACL
# 1    Area A (Information Extraction and Question An...          1017
# 2    Area A (Information Extraction and Question An...          1989
# 3    Area A (Information Extraction and Question An...          2043
# 4    Area A (Information Extraction and Question An...          2134
# ..                                                 ...           ...
# 458                   Area H (Machine Learning) [LONG]           204
# 459                   Area H (Machine Learning) [LONG]          1198
# 460                   Area H (Machine Learning) [LONG]          1111
# 461                                        Area H or D     1379-TACL
# 462                                        Area H or D     1396-TACL
#
#                                       Submission Title  \
# 0    Joint Multitask Learning for Community Questio...
# 1    What Makes Reading Comprehension Questions Eas...
# 2    Commonsense for Generative Multi-Hop Question ...
# 3    Open Domain Question Answering Using Early Fus...
# 4    A Nil-Aware Answer Extraction Framework for Qu...
# ..                                                 ...
# 458  The importance of Being Recurrent for Modeling...
# 459  Towards Dynamic Computation Graphs via Sparse ...
# 460  Convolutional Neural Networks with Recurrent N...
# 461  Language Modeling for Morphologically Rich Lan...
# 462  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                                Authors
# 0         Shafiq Joty, Lluís Màrquez and Preslav Nakov
# 1    Saku Sugawara, Kentaro Inui, Satoshi Sekine an...
# 2            Lisa Bauer, Yicheng Wang and Mohit Bansal
# 3    Haitian Sun, Bhuwan Dhingra, Manzil Zaheer, Ka...
# 4                         Souvik Kundu and Hwee Tou Ng
# ..                                                 ...
# 458         Ke Tran, Arianna Bisazza and Christof Monz
# 459  Vlad Niculae, André F. T. Martins and Claire C...
# 460                                            Yi Yang
# 461  Daniela Gerz, Ivan Vulić, Edoardo Maria Ponti,...
# 462                     Aaron Jaech and Mari Ostendorf
#
# [463 rows x 4 columns]

# %%
set(df['Track']) # interpretabilty does not have a track
# Out:
# {'Area A (Information Extraction and Question Answering) [LONG]',
#  'Area A from Area F (Discourse, Dialog, Summarization, Generation, Multimodal NLP) [LONG]',
#  'Area B (Text Mining and Information Retrieval) [LONG]',
#  'Area C (Social Media, Computational Social Science, Sentiment,  Opinion) [LONG]',
#  'Area D (Morphology, Syntax, Chunking, Psycholinguistics) [LONG]',
#  'Area E (Semantics) [LONG]',
#  'Area F (Discourse, Dialog, Summarization, Generation, Multimodal NLP) [LONG]',
#  'Area G (Machine Translation and Multilinguality) [LONG]',
#  'Area H (Machine Learning) [LONG]',
#  'Area H or D'}

# %%
new_df = pd.DataFrame()
new_df['id'] = df['Submission ID']
new_df['title'] = df['Submission Title']
new_df['area'] = df['Track']
new_df['interpretability'] = None
new_df['source'] = 'EMNLP2018'

new_df
# Out:
#             id                                              title  \
# 0     587-TACL  Joint Multitask Learning for Community Questio...
# 1         1017  What Makes Reading Comprehension Questions Eas...
# 2         1989  Commonsense for Generative Multi-Hop Question ...
# 3         2043  Open Domain Question Answering Using Early Fus...
# 4         2134  A Nil-Aware Answer Extraction Framework for Qu...
# ..         ...                                                ...
# 458        204  The importance of Being Recurrent for Modeling...
# 459       1198  Towards Dynamic Computation Graphs via Sparse ...
# 460       1111  Convolutional Neural Networks with Recurrent N...
# 461  1379-TACL  Language Modeling for Morphologically Rich Lan...
# 462  1396-TACL  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                                   area interpretability  \
# 0    Area A (Information Extraction and Question An...             None
# 1    Area A (Information Extraction and Question An...             None
# 2    Area A (Information Extraction and Question An...             None
# 3    Area A (Information Extraction and Question An...             None
# 4    Area A (Information Extraction and Question An...             None
# ..                                                 ...              ...
# 458                   Area H (Machine Learning) [LONG]             None
# 459                   Area H (Machine Learning) [LONG]             None
# 460                   Area H (Machine Learning) [LONG]             None
# 461                                        Area H or D             None
# 462                                        Area H or D             None
#
#         source
# 0    EMNLP2018
# 1    EMNLP2018
# 2    EMNLP2018
# 3    EMNLP2018
# 4    EMNLP2018
# ..         ...
# 458  EMNLP2018
# 459  EMNLP2018
# 460  EMNLP2018
# 461  EMNLP2018
# 462  EMNLP2018
#
# [463 rows x 5 columns]

# %%
new_df['doi'] = new_df['title'].apply(get_acl_anthology_doi)
new_df
# Out:
#             id                                              title  \
# 0     587-TACL  Joint Multitask Learning for Community Questio...
# 1         1017  What Makes Reading Comprehension Questions Eas...
# 2         1989  Commonsense for Generative Multi-Hop Question ...
# 3         2043  Open Domain Question Answering Using Early Fus...
# 4         2134  A Nil-Aware Answer Extraction Framework for Qu...
# ..         ...                                                ...
# 458        204  The importance of Being Recurrent for Modeling...
# 459       1198  Towards Dynamic Computation Graphs via Sparse ...
# 460       1111  Convolutional Neural Networks with Recurrent N...
# 461  1379-TACL  Language Modeling for Morphologically Rich Lan...
# 462  1396-TACL  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                                   area interpretability  \
# 0    Area A (Information Extraction and Question An...             None
# 1    Area A (Information Extraction and Question An...             None
# 2    Area A (Information Extraction and Question An...             None
# 3    Area A (Information Extraction and Question An...             None
# 4    Area A (Information Extraction and Question An...             None
# ..                                                 ...              ...
# 458                   Area H (Machine Learning) [LONG]             None
# 459                   Area H (Machine Learning) [LONG]             None
# 460                   Area H (Machine Learning) [LONG]             None
# 461                                        Area H or D             None
# 462                                        Area H or D             None
#
#         source                   doi
# 0    EMNLP2018  10.18653/v1/D18-1452
# 1    EMNLP2018  10.18653/v1/D18-1453
# 2    EMNLP2018  10.18653/v1/D18-1454
# 3    EMNLP2018  10.18653/v1/D18-1455
# 4    EMNLP2018  10.18653/v1/D18-1456
# ..         ...                   ...
# 458  EMNLP2018  10.18653/v1/D18-1503
# 459  EMNLP2018  10.18653/v1/D18-1108
# 460  EMNLP2018  10.18653/v1/D18-1109
# 461  EMNLP2018  10.1162/tacl_a_00032
# 462  EMNLP2018  10.1162/tacl_a_00035
#
# [463 rows x 6 columns]

# %% [markdown]
# # Saving the results

# %%
previous_df = pd.read_csv('../data/parsed_data.csv')
previous_df = previous_df.drop('Unnamed: 0', axis=1)
previous_df
# Out:
#             id                                              title  \
# 0     587-TACL  Joint Multitask Learning for Community Questio...
# 1         1017  What Makes Reading Comprehension Questions Eas...
# 2         1989  Commonsense for Generative Multi-Hop Question ...
# 3         2043  Open Domain Question Answering Using Early Fus...
# 4         2134  A Nil-Aware Answer Extraction Framework for Qu...
# ...        ...                                                ...
# 9805      3525  LOT: A Story-Centric Benchmark for Evaluating ...
# 9806      3539  Time-Aware Language Models as Temporal Knowled...
# 9807      3567  Designing an Automatic Agent for Repeated Lang...
# 9808      3607  TopiOCQA: Open-domain Conversational Question ...
# 9809     18410  Novelty Detection: A Perspective from Natural ...
#
#                                                    area interpretability  \
# 0     Area A (Information Extraction and Question An...              NaN
# 1     Area A (Information Extraction and Question An...              NaN
# 2     Area A (Information Extraction and Question An...              NaN
# 3     Area A (Information Extraction and Question An...              NaN
# 4     Area A (Information Extraction and Question An...              NaN
# ...                                                 ...              ...
# 9805                           Resources and Evaluation            False
# 9806                                 Question Answering            False
# 9807                   Dialogue and Interactive Systems            False
# 9808                   Dialogue and Interactive Systems            False
# 9809                                   NLP Applications            False
#
#                        doi     source
# 0     10.18653/v1/D18-1452  EMNLP2018
# 1     10.18653/v1/D18-1453  EMNLP2018
# 2     10.18653/v1/D18-1454  EMNLP2018
# 3     10.18653/v1/D18-1455  EMNLP2018
# 4     10.18653/v1/D18-1456  EMNLP2018
# ...                    ...        ...
# 9805  10.1162/tacl_a_00469    ACL2022
# 9806  10.1162/tacl_a_00459    ACL2022
# 9807                   NaN    ACL2022
# 9808  10.1162/tacl_a_00471    ACL2022
# 9809  10.1162/coli_a_00429    ACL2022
#
# [9810 rows x 6 columns]

# %%
# we'll delete previous rows from the conference
previous_df = previous_df[previous_df['source'] != 'EMNLP2018']
previous_df
# Out:
#          id                                              title  \
# 463    s438        Detecting Attackable Sentences in Arguments
# 464    s440  Extracting Implicitly Asserted Propositions in...
# 465   s2688  Quantitative Argument Summarization and Beyond...
# 466   s2996  Unsupervised Stance Detection for Arguments fr...
# 467     s84  BLEU might be Guilty but References are not In...
# ...     ...                                                ...
# 9805   3525  LOT: A Story-Centric Benchmark for Evaluating ...
# 9806   3539  Time-Aware Language Models as Temporal Knowled...
# 9807   3567  Designing an Automatic Agent for Repeated Lang...
# 9808   3607  TopiOCQA: Open-domain Conversational Question ...
# 9809  18410  Novelty Detection: A Perspective from Natural ...
#
#                                                    area interpretability  \
# 463   Sentiment Analysis, Stylistic Analysis, and Ar...            False
# 464   Sentiment Analysis, Stylistic Analysis, and Ar...            False
# 465   Sentiment Analysis, Stylistic Analysis, and Ar...            False
# 466   Sentiment Analysis, Stylistic Analysis, and Ar...            False
# 467   Sentiment Analysis, Stylistic Analysis, and Ar...            False
# ...                                                 ...              ...
# 9805                           Resources and Evaluation            False
# 9806                                 Question Answering            False
# 9807                   Dialogue and Interactive Systems            False
# 9808                   Dialogue and Interactive Systems            False
# 9809                                   NLP Applications            False
#
#                                 doi     source
# 463   10.18653/v1/2020.emnlp-main.1  EMNLP2020
# 464   10.18653/v1/2020.emnlp-main.2  EMNLP2020
# 465   10.18653/v1/2020.emnlp-main.3  EMNLP2020
# 466   10.18653/v1/2020.emnlp-main.4  EMNLP2020
# 467   10.18653/v1/2020.emnlp-main.5  EMNLP2020
# ...                             ...        ...
# 9805           10.1162/tacl_a_00469    ACL2022
# 9806           10.1162/tacl_a_00459    ACL2022
# 9807                            NaN    ACL2022
# 9808           10.1162/tacl_a_00471    ACL2022
# 9809           10.1162/coli_a_00429    ACL2022
#
# [9347 rows x 6 columns]

# %%
updated_df = pd.concat([previous_df, new_df], ignore_index=True)
updated_df
# Out:
#              id                                              title  \
# 0          s438        Detecting Attackable Sentences in Arguments
# 1          s440  Extracting Implicitly Asserted Propositions in...
# 2         s2688  Quantitative Argument Summarization and Beyond...
# 3         s2996  Unsupervised Stance Detection for Arguments fr...
# 4           s84  BLEU might be Guilty but References are not In...
# ...         ...                                                ...
# 9805        204  The importance of Being Recurrent for Modeling...
# 9806       1198  Towards Dynamic Computation Graphs via Sparse ...
# 9807       1111  Convolutional Neural Networks with Recurrent N...
# 9808  1379-TACL  Language Modeling for Morphologically Rich Lan...
# 9809  1396-TACL  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                                    area interpretability  \
# 0     Sentiment Analysis, Stylistic Analysis, and Ar...            False
# 1     Sentiment Analysis, Stylistic Analysis, and Ar...            False
# 2     Sentiment Analysis, Stylistic Analysis, and Ar...            False
# 3     Sentiment Analysis, Stylistic Analysis, and Ar...            False
# 4     Sentiment Analysis, Stylistic Analysis, and Ar...            False
# ...                                                 ...              ...
# 9805                   Area H (Machine Learning) [LONG]             None
# 9806                   Area H (Machine Learning) [LONG]             None
# 9807                   Area H (Machine Learning) [LONG]             None
# 9808                                        Area H or D             None
# 9809                                        Area H or D             None
#
#                                 doi     source
# 0     10.18653/v1/2020.emnlp-main.1  EMNLP2020
# 1     10.18653/v1/2020.emnlp-main.2  EMNLP2020
# 2     10.18653/v1/2020.emnlp-main.3  EMNLP2020
# 3     10.18653/v1/2020.emnlp-main.4  EMNLP2020
# 4     10.18653/v1/2020.emnlp-main.5  EMNLP2020
# ...                             ...        ...
# 9805           10.18653/v1/D18-1503  EMNLP2018
# 9806           10.18653/v1/D18-1108  EMNLP2018
# 9807           10.18653/v1/D18-1109  EMNLP2018
# 9808           10.1162/tacl_a_00032  EMNLP2018
# 9809           10.1162/tacl_a_00035  EMNLP2018
#
# [9810 rows x 6 columns]

# %%
updated_df.to_csv('../data/parsed_data.csv')
