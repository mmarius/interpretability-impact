# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))
from utils import *
import pandas as pd
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
ACCEPTED_PAPERS_SHEET = 6
df = pd.read_excel('../data/emnlp2023/EMNLP 2023 papers and schedule.xlsx', sheet_name=ACCEPTED_PAPERS_SHEET)
df
# Out:
#      Paper Number                                              Title  \
# 0               6  APrompt: Attention Prompt Tuning for Efficient...
# 1              11  AfriSenti: A Twitter Sentiment Analysis Benchm...
# 2              13  MemeCap: A Dataset for Captioning and Interpre...
# 3              14  Towards Noise-Tolerant Speech-Referring Video ...
# 4              18  Incorporating Structured Representations into ...
# ...           ...                                                ...
# 1042      ARR 113  Zero-Shot Multi-Label Topic Inference with Sen...
# 1043      ARR 116         ALCAP: Alignment-Augmented Music Captioner
# 1044      ARR 117  Not all Fake News is Written: A Dataset and An...
# 1045      ARR 121  Automated Fact-Checking in Dialogue: Are Speci...
# 1046      ARR 123  Exploring Distributional Shifts in Large Langu...
#
#                                        Submission Track     Decision  \
# ...

# %%
set(df['Decision'])
# Out:
# {'Accept-Main'}

# %%
set(df['Submission Track'])
# Out:
# {'Commonsense Reasoning',
#  'Computational Social Science and Cultural Analytics',
#  'Dialogue and Interactive Systems',
#  'Discourse and Pragmatics',
#  'Efficient Methods for NLP',
#  'Ethics in NLP',
#  'Human-Centered NLP',
#  'Information Extraction',
#  'Information Retrieval and Text Mining',
#  'Interpretability, Interactivity, and Analysis of Models for NLP',
#  'Language Grounding to Vision, Robotics and Beyond',
#  'Language Modeling and Analysis of Language Models',
#  'Linguistic Theories, Cognitive Modeling, and Psycholinguistics',
#  'Machine Learning for NLP',
#  'Machine Translation',
#  'Multilinguality and Linguistic Diversity',
#  'NLP Applications',
#  'Natural Language Generation',
#  'Phonology, Morphology, and Word Segmentation',
#  'Question Answering',
#  'Resources and Evaluation',
#  'Semantics: Lexical, Sentence level, Document Level, Textual Inference, etc.',
#  'Sentiment Analysis, Stylistic Analysis, and Argument Mining',
# ...

# %%
new_df = pd.DataFrame()
new_df['id'] = df['Paper Number']
new_df['title'] = df['Title']
new_df['area'] = df['Submission Track']
new_df['source'] = 'EMNLP'
new_df['year'] = 2023
new_df['doi'] = None
new_df['abstract'] = None

new_df
# Out:
#            id                                              title  \
# 0           6  APrompt: Attention Prompt Tuning for Efficient...
# 1          11  AfriSenti: A Twitter Sentiment Analysis Benchm...
# 2          13  MemeCap: A Dataset for Captioning and Interpre...
# 3          14  Towards Noise-Tolerant Speech-Referring Video ...
# 4          18  Incorporating Structured Representations into ...
# ...       ...                                                ...
# 1042  ARR 113  Zero-Shot Multi-Label Topic Inference with Sen...
# 1043  ARR 116         ALCAP: Alignment-Augmented Music Captioner
# 1044  ARR 117  Not all Fake News is Written: A Dataset and An...
# 1045  ARR 121  Automated Fact-Checking in Dialogue: Are Speci...
# 1046  ARR 123  Exploring Distributional Shifts in Large Langu...
#
#                                                    area source  year   doi  \
# 0                             Efficient Methods for NLP  EMNLP  2023  None
# ...

# %% [markdown]
# # Saving the results

# %%
previous_df = pd.read_csv('../data/cl_papers.csv', index_col=0)
previous_df
# Out:
#              id                                              title  \
# 0     main.1004  AnswerFact: Fact Checking in Product Question ...
# 1     main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2     main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3     main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4     main.1011  Knowledge Association with Hyperbolic Knowledg...
# ...         ...                                                ...
# 4741       3525  LOT: A Story-Centric Benchmark for Evaluating ...
# 4742       3539  Time-Aware Language Models as Temporal Knowled...
# 4743       3567  Designing an Automatic Agent for Repeated Lang...
# 4744       3607  TopiOCQA: Open-domain Conversational Question ...
# 4745      18410  Novelty Detection: A Perspective from Natural ...
#
#                                   area source  year  \
# 0                   Question Answering  EMNLP  2020
# 1       Dialog and Interactive Systems  EMNLP  2020
# ...

# %%
# we'll delete previous rows from the conference
previous_df = previous_df[~((previous_df['source'] == 'EMNLP') & (previous_df['year'] == 2023))]
previous_df
# Out:
#              id                                              title  \
# 0     main.1004  AnswerFact: Fact Checking in Product Question ...
# 1     main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2     main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3     main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4     main.1011  Knowledge Association with Hyperbolic Knowledg...
# ...         ...                                                ...
# 4741       3525  LOT: A Story-Centric Benchmark for Evaluating ...
# 4742       3539  Time-Aware Language Models as Temporal Knowled...
# 4743       3567  Designing an Automatic Agent for Repeated Lang...
# 4744       3607  TopiOCQA: Open-domain Conversational Question ...
# 4745      18410  Novelty Detection: A Perspective from Natural ...
#
#                                   area source  year  \
# 0                   Question Answering  EMNLP  2020
# 1       Dialog and Interactive Systems  EMNLP  2020
# ...

# %%
updated_df = pd.concat([previous_df, new_df], ignore_index=True)
updated_df
# Out:
#              id                                              title  \
# 0     main.1004  AnswerFact: Fact Checking in Product Question ...
# 1     main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2     main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3     main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4     main.1011  Knowledge Association with Hyperbolic Knowledg...
# ...         ...                                                ...
# 5788    ARR 113  Zero-Shot Multi-Label Topic Inference with Sen...
# 5789    ARR 116         ALCAP: Alignment-Augmented Music Captioner
# 5790    ARR 117  Not all Fake News is Written: A Dataset and An...
# 5791    ARR 121  Automated Fact-Checking in Dialogue: Are Speci...
# 5792    ARR 123  Exploring Distributional Shifts in Large Langu...
#
#                                                    area source  year  \
# 0                                    Question Answering  EMNLP  2020
# ...

# %%
updated_df.to_csv('../data/cl_papers.csv')
