# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))
from utils import *
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
url = 'https://acl2018.org/programme/schedule/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
papers = []
day_schedules = soup.find_all(class_='day-program')
for day in day_schedules:
    rows = day.find_all('tr')
    current_titles = []
    for row in rows:
        is_area_track_info_row = 'session-name-row' in row['class'] and 'conc-session-indiv-row' in row['class']
        is_orals_papers_row = 'conc-session-details-row' in row['class']
        is_poster_papers_row = 'poster-session-row' in row['class'] and len(list(row.children)) > 1
        if is_area_track_info_row:
            title_divs = row.find_all(class_='conc-session-name')
            title_regex = r'Session \d+[A-Za-z]*: (.*?)\s*\d*$'
            current_titles = [re.search(title_regex, div.text).group(1) for div in title_divs]
        elif is_orals_papers_row:
            papers_per_area = row.find_all('td')
            assert len(papers_per_area) == len(current_titles)
            for paper_column, area in zip(papers_per_area, current_titles):
                for paper_div in paper_column.find_all('div', class_='talk-title'):
                    paper_link_index = 2
                    links = paper_div.find_all('a')
                    paper_link = links[paper_link_index]
                    paper_id = paper_link['href'].split('/')[-1]
                    title = paper_link.text
                    papers.append({'id': paper_id, 'title': title, 'area': area})
            current_titles = []
        elif is_poster_papers_row:
            # print(row)
            poster_subsessions = row.find_all(class_='poster-sub-session')
            for subsession in poster_subsessions:
                raw_track_title = subsession.find(class_='poster-session-name').text
                if raw_track_title == 'Tutorial':
                    continue
                title_regex = r'Poster Session \d+[A-Za-z]*: (.*?)$'
                track = re.search(title_regex, raw_track_title).group(1)
                for paper_span in subsession.find_all('span'):
                    links = paper_span.find_all('a')
                    paper_link_index = 1
                    paper_link = links[paper_link_index]
                    paper_id = paper_link['href'].split('/')[-1]
                    title = paper_link.text
                    papers.append({'id': paper_id, 'title': title, 'area': track})
 
df = pd.DataFrame(papers)
df
# Out:
#        id                                              title  \
# 0     187  Probabilistic FastText for Multi-Sense Word Em...
# 1    1520  A La Carte Embedding: Cheap but Effective Indu...
# 2     707  Unsupervised Learning of Distributional Relati...
# 3    1553  Explicit Retrofitting of Distributional Word V...
# 4      76  Unsupervised Neural Machine Translation with W...
# ..    ...                                                ...
# 442  1125  Know What You Don’t Know: Unanswerable Questio...
# 443  1603  'Lighter' Can Still Be Dark: Modeling Comparat...
# 444   618  Finding syntax in human encephalography with b...
# 445  1247  Learning to Ask Good Questions: Ranking Clarif...
# 446  1348  Let's do it ``again'': A First Computational A...
#
#                     area
# 0         Word Semantics
# 1         Word Semantics
# 2         Word Semantics
# 3         Word Semantics
# 4    Machine Translation
# ..                   ...
# 442   Best Paper Session
# 443   Best Paper Session
# 444   Best Paper Session
# 445   Best Paper Session
# 446   Best Paper Session
#
# [447 rows x 3 columns]

# %%
# there is no interpretability area
areas = set(list(df['area']))
areas
# Out:
# {'Argument Mining',
#  'Best Paper Session',
#  'Dialog System',
#  'Dialog System, Discourse',
#  'Dialog and Interactive Systems, Multilinguality',
#  'Discourse',
#  'Discourse, Linguistics, Cognitive Modeling',
#  'Document Analysis',
#  'Evaluation',
#  'Generation',
#  'Generation, Summarization',
#  'Inference, Reasoning',
#  'Information Extraction',
#  'Information Extraction, Text Mining',
#  'Information Retrieval',
#  'Language/Document Model',
#  'Linguistics, Psycholinguistics and Cognitive Modeling',
#  'Machine Learning',
#  'Machine Learning, Question Answering',
#  'Machine Translation',
#  'Machine Translation, Multilinguality',
#  'Morphology, Tagging, Parsing',
#  'Multilinguality',
#  'Multimodal',
#  'Parsing',
#  'Parsing, Morphology',
#  'Question Answering',
#  'Resource, Annotation',
#  'Resources and Evaluation',
#  'Semantic Parsing',
#  'Semantics',
#  'Sentiment',
#  'Sentiment Analysis and Argument Mining',
#  'Social Media',
#  'Student Research Workshop',
#  'Summarization',
#  'Summarization, Social Media',
#  'System Demonstrations',
#  'Text Mining and Applications',
#  'Vision',
#  'Vision, Linguistics, Resource and Evaluation',
#  'Vision, Multimodal, Grounding, Speech',
#  'Word Semantics'}

# %%
df['interpretability'] = None
df['doi'] = df['title'].apply(get_acl_anthology_doi)
df
# Out:
#        id                                              title  \
# 0     187  Probabilistic FastText for Multi-Sense Word Em...
# 1    1520  A La Carte Embedding: Cheap but Effective Indu...
# 2     707  Unsupervised Learning of Distributional Relati...
# 3    1553  Explicit Retrofitting of Distributional Word V...
# 4      76  Unsupervised Neural Machine Translation with W...
# ..    ...                                                ...
# 442  1125  Know What You Don’t Know: Unanswerable Questio...
# 443  1603  'Lighter' Can Still Be Dark: Modeling Comparat...
# 444   618  Finding syntax in human encephalography with b...
# 445  1247  Learning to Ask Good Questions: Ranking Clarif...
# 446  1348  Let's do it ``again'': A First Computational A...
#
#                     area interpretability   source                   doi
# 0         Word Semantics             None  ACL2018  10.18653/v1/P18-1001
# 1         Word Semantics             None  ACL2018  10.18653/v1/P18-1002
# 2         Word Semantics             None  ACL2018  10.18653/v1/P18-1003
# 3         Word Semantics             None  ACL2018  10.18653/v1/P18-1004
# 4    Machine Translation             None  ACL2018  10.18653/v1/P18-1005
# ..                   ...              ...      ...                   ...
# 442   Best Paper Session             None  ACL2018  10.18653/v1/P18-2124
# 443   Best Paper Session             None  ACL2018                  None
# 444   Best Paper Session             None  ACL2018  10.18653/v1/P18-1254
# 445   Best Paper Session             None  ACL2018  10.18653/v1/P18-1255
# 446   Best Paper Session             None  ACL2018                  None
#
# [447 rows x 6 columns]

# %%
previous_df = pd.read_csv('../data/parsed_data.csv')
previous_df = previous_df.drop('Unnamed: 0', axis=1)
previous_df
# Out:
#          id                                              title  \
# 0       797  Restricted Recurrent Neural Tensor Networks: E...
# 1       338  Neural Hidden Markov Model for Machine Transla...
# 2       300  Attention Focusing for Neural Machine Translat...
# 3      1638  Will it Blend? Blending Weak and Strong Labele...
# 4        92  Batch IS NOT Heavy: Learning Word Representati...
# ...     ...                                                ...
# 9524  T4773  Rank-Aware Negative Training for Semi-Supervis...
# 9525  T4777  Transparency Helps Reveal When Language Models...
# 9526  T4803  Design Choices for Crowdsourcing Implicit Disc...
# 9527  T4929        Time-and-Space-Efficient Weighted Deduction
# 9528  T5043  Collective Human Opinions in Semantic Textual ...
#
#                                                    area interpretability  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 9524                           Machine Learning for NLP            False
# 9525  Linguistic Theories, Cognitive Modeling, and P...            False
# 9526                           Discourse and Pragmatics            False
# 9527  Semantics: Sentence-level Semantics, Textual I...            False
# 9528  Semantics: Sentence-level Semantics, Textual I...            False
#
#                        doi   source
# 0     10.18653/v1/P18-2002  ACL2019
# 1     10.18653/v1/P18-2060  ACL2019
# 2     10.18653/v1/P18-1164  ACL2019
# 3     10.18653/v1/P18-2095  ACL2019
# 4     10.18653/v1/P18-1172  ACL2019
# ...                    ...      ...
# 9524  10.1162/tacl_a_00574  ACL2023
# 9525  10.1162/tacl_a_00565  ACL2023
# 9526  10.1162/tacl_a_00586  ACL2023
# 9527  10.1162/tacl_a_00588  ACL2023
# 9528  10.1162/tacl_a_00584  ACL2023
#
# [9529 rows x 6 columns]

# %%
updated_df = pd.concat([previous_df, df], ignore_index=True)
updated_df
# Out:
#         id                                              title  \
# 0      797  Restricted Recurrent Neural Tensor Networks: E...
# 1      338  Neural Hidden Markov Model for Machine Transla...
# 2      300  Attention Focusing for Neural Machine Translat...
# 3     1638  Will it Blend? Blending Weak and Strong Labele...
# 4       92  Batch IS NOT Heavy: Learning Word Representati...
# ...    ...                                                ...
# 9971  1125  Know What You Don’t Know: Unanswerable Questio...
# 9972  1603  'Lighter' Can Still Be Dark: Modeling Comparat...
# 9973   618  Finding syntax in human encephalography with b...
# 9974  1247  Learning to Ask Good Questions: Ranking Clarif...
# 9975  1348  Let's do it ``again'': A First Computational A...
#
#                     area interpretability                   doi   source
# 0                    NaN              NaN  10.18653/v1/P18-2002  ACL2019
# 1                    NaN              NaN  10.18653/v1/P18-2060  ACL2019
# 2                    NaN              NaN  10.18653/v1/P18-1164  ACL2019
# 3                    NaN              NaN  10.18653/v1/P18-2095  ACL2019
# 4                    NaN              NaN  10.18653/v1/P18-1172  ACL2019
# ...                  ...              ...                   ...      ...
# 9971  Best Paper Session             None  10.18653/v1/P18-2124  ACL2018
# 9972  Best Paper Session             None                  None  ACL2018
# 9973  Best Paper Session             None  10.18653/v1/P18-1254  ACL2018
# 9974  Best Paper Session             None  10.18653/v1/P18-1255  ACL2018
# 9975  Best Paper Session             None                  None  ACL2018
#
# [9976 rows x 6 columns]

# %%
updated_df.to_csv('../data/parsed_data.csv')
