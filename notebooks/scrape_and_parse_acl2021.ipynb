# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))
from utils import *
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
import requests

INTERPRETABILITY_AREA_ID = 9364
url = "https://acl2021.semanticpaths.org/api"

headers = {
    "accept": "*/*",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
}

def get_interpretability_papers(start=0):
    data = {
        "op": "GET_PAGINATED_RELATED",
        "graph": '{{"id":"{}","order":1,"pinned":false,"freeText":false}}'.format(INTERPRETABILITY_AREA_ID),
        "language": "EN",
        "nodeEntity": "DOCUMENT",
        "start": str(start),
        "filterSources": "CONFERENCE"
    }
    
    

    response = requests.post(url, headers=headers, data=data).json()
    return response['content']['related']['DOCUMENT']['elements']

# %%
start = 0
papers = []
while True:
    new_papers = get_interpretability_papers(start=start)
    papers += new_papers
    if len(new_papers) != 10:
        break
    start += 10

# %%
data = []
for paper in papers:
    title = paper['label']['text']
    paper_id = paper['id']
    area = 'Interpretability and Analysis of Models for NLP'
    
    data.append({ 'title': title, 'id': paper_id, 'area': area })
    
df = pd.DataFrame(data)
df
# Out:
#                                                 title     id  \
# 0      Attention Flows are Shapley Value Explanations   9765
# 1   Intrinsic Dimensionality Explains the Effectiv...   9577
# 2   More Identifiable yet Equally Performant Trans...  10000
# 3   Analyzing the Source and Target Contributions ...   9447
# 4   What Context Features Can Transformer Language...  10506
# ..                                                ...    ...
# 60  Using Adversarial Attacks to Reveal the Statis...   9758
# 61  Inspecting the concept knowledge graph encoded...   9880
# 62  Integrated Directional Gradients: Feature Inte...   9436
# 63           Perceptual Models of Machine-Edited Text   9767
# 64  On Sample Based Explanation Methods for NLP: F...  10269
#
#                                                area
# 0   Interpretability and Analysis of Models for NLP
# 1   Interpretability and Analysis of Models for NLP
# 2   Interpretability and Analysis of Models for NLP
# ...

# %%
df['interpretability'] = True
df['source'] = 'ACL2021'
df
# Out:
#                                                 title     id  \
# 0      Attention Flows are Shapley Value Explanations   9765
# 1   Intrinsic Dimensionality Explains the Effectiv...   9577
# 2   More Identifiable yet Equally Performant Trans...  10000
# 3   Analyzing the Source and Target Contributions ...   9447
# 4   What Context Features Can Transformer Language...  10506
# ..                                                ...    ...
# 60  Using Adversarial Attacks to Reveal the Statis...   9758
# 61  Inspecting the concept knowledge graph encoded...   9880
# 62  Integrated Directional Gradients: Feature Inte...   9436
# 63           Perceptual Models of Machine-Edited Text   9767
# 64  On Sample Based Explanation Methods for NLP: F...  10269
#
#                                                area  interpretability   source
# 0   Interpretability and Analysis of Models for NLP              True  ACL2021
# ...

# %%
df['doi'] = df['title'].apply(get_acl_anthology_doi)
df
# Out:
#                                                 title     id  \
# 0      Attention Flows are Shapley Value Explanations   9765
# 1   Intrinsic Dimensionality Explains the Effectiv...   9577
# 2   More Identifiable yet Equally Performant Trans...  10000
# 3   Analyzing the Source and Target Contributions ...   9447
# 4   What Context Features Can Transformer Language...  10506
# ..                                                ...    ...
# 60  Using Adversarial Attacks to Reveal the Statis...   9758
# 61  Inspecting the concept knowledge graph encoded...   9880
# 62  Integrated Directional Gradients: Feature Inte...   9436
# 63           Perceptual Models of Machine-Edited Text   9767
# 64  On Sample Based Explanation Methods for NLP: F...  10269
#
#                                                area  interpretability  \
# 0   Interpretability and Analysis of Models for NLP              True
# 1   Interpretability and Analysis of Models for NLP              True
# ...

# %%
previous_df = pd.read_csv('../data/parsed_data.csv')
previous_df = previous_df.drop('Unnamed: 0', axis=1)
previous_df
# Out:
#              id                                              title  \
# 0            21  Pre-training Multi-party Dialogue Models with ...
# 1            23  Dual-Gated Fusion with Prefix-Tuning for Multi...
# 2            25                Aerial Vision-and-Dialog Navigation
# 3            34  Fixing MoE Over-Fitting on Low-Resource Langua...
# 4            35  A Survey of Deep Learning for Mathematical Rea...
# ...         ...                                                ...
# 9718  tacl.1886  A Knowledge-Enhanced Pretraining Model for Com...
# 9719  tacl.1892  Does Syntax Need to Grow on Trees? Sources of ...
# 9720  tacl.1759          Phonotactic Complexity and Its Trade-offs
# 9721  tacl.1834  Acoustic-Prosodic and Lexical Cues to Deceptio...
# 9722  tacl.1766  Efficient Contextual Representation Learning W...
#
#                                                  area interpretability  \
# 0                                      Virtual Poster              NaN
# ...

# %%
updated_df = pd.concat([previous_df, df], ignore_index=True)
updated_df
# Out:
#          id                                              title  \
# 0        21  Pre-training Multi-party Dialogue Models with ...
# 1        23  Dual-Gated Fusion with Prefix-Tuning for Multi...
# 2        25                Aerial Vision-and-Dialog Navigation
# 3        34  Fixing MoE Over-Fitting on Low-Resource Langua...
# 4        35  A Survey of Deep Learning for Mathematical Rea...
# ...     ...                                                ...
# 9783   9758  Using Adversarial Attacks to Reveal the Statis...
# 9784   9880  Inspecting the concept knowledge graph encoded...
# 9785   9436  Integrated Directional Gradients: Feature Inte...
# 9786   9767           Perceptual Models of Machine-Edited Text
# 9787  10269  On Sample Based Explanation Methods for NLP: F...
#
#                                                  area interpretability  \
# 0                                      Virtual Poster              NaN
# ...

# %%
updated_df.to_csv('../data/parsed_data.csv')
