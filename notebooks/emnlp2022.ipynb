# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))
from utils import *
import pandas as pd

# %%
df = pd.read_excel('../data/emnlp2022/Accepted-Papers.xls')
df
# Out:
#       Submission ID                                              Title  \
# 0               114  LogicSolver: Towards Interpretable Math Word P...
# 1               127  Commonsense Knowledge Salience Evaluation with...
# 2               138  Automatic Rule Induction for Efficient Semi-Su...
# 3               143  Improving Semantic Matching through Dependency...
# 4               150  Sparse Mixers: Combining MoE and Mixing to bui...
# ...             ...                                                ...
# 1372           4608  PAR: Political Actor Representation Learning w...
# 1373           4613  JDDC 2.1: A Multimodal Chinese Dialogue Datase...
# 1374           4618  PCL: Peer-Contrastive Learning with Diverse Au...
# 1375           4621  Digging Errors in NMT: Evaluating and Understa...
# 1376           4622  DialogConv: A Lightweight Fully Convolutional ...
#
#      Acceptance Status                                              Track  \
# ...

# %%
set(df['Acceptance Status'])
# Out:
# {'Accept-Findings', 'Accept-Oral', 'Accept-Poster'}

# %%
df = df[df['Acceptance Status'] != 'Accept-Findings'].copy()
df
# Out:
#       Submission ID                                              Title  \
# 548             123  Generative Knowledge Graph Construction: A Review
# 549             142  CDConv: A Benchmark for Contradiction Detectio...
# 550             164  Transformer Feed-Forward Layers Build Predicti...
# 551             168  Learning to Generate Question by Asking Questi...
# 552             236  Graph-based Model Generation for Few-Shot Rela...
# ...             ...                                                ...
# 1372           4608  PAR: Political Actor Representation Learning w...
# 1373           4613  JDDC 2.1: A Multimodal Chinese Dialogue Datase...
# 1374           4618  PCL: Peer-Contrastive Learning with Diverse Au...
# 1375           4621  Digging Errors in NMT: Evaluating and Understa...
# 1376           4622  DialogConv: A Lightweight Fully Convolutional ...
#
#      Acceptance Status                                              Track  \
# ...

# %%
set(df['Track'])
# Out:
# {'Commonsense Reasoning',
#  'Computational Social Science and Cultural Analytics',
#  'Dialogue and Interactive Systems',
#  'Discourse and Pragmatics',
#  'Efficient Methods for NLP',
#  'Ethic Concerns:Dialogue and Interactive Systems',
#  'Ethic Concerns:Ethics',
#  'Ethic Concerns:Linguistic Theories, Cognitive Modeling and Psycholinguistics',
#  'Ethic Concerns:Multilinguality',
#  'Ethic Concerns:NLP Applications',
#  'Ethic Concerns:Resources and Evaluation',
#  'Ethic Concerns:Sentiment Analysis, Stylistic Analysis, and Argument Mining',
#  'Ethic Concerns:Speech, Vision, Robotics, Multimodal Grounding',
#  'Ethic Concerns:Unsupervised and Weakly-Supervised Methods in NLP',
#  'Ethics',
#  'Information Extraction',
#  'Information Retrieval and Text Mining',
#  'Interpretability, Interactivity and Analysis of Models for NLP',
#  'Language Modeling and Analysis of Language Models',
#  'Linguistic Theories, Cognitive Modeling and Psycholinguistics',
# ...

# %%
research_areas_ethics = {
    'Commonsense Reasoning': False,
    'Computational Social Science and Cultural Analytics': False,
    'Dialogue and Interactive Systems': False,
    'Discourse and Pragmatics': False,
    'Efficient Methods for NLP': False,
    'Ethic Concerns:Computational Social Science and Cultural Analytics': False,
    'Ethic Concerns:Dialogue and Interactive Systems': False,
    'Ethic Concerns:Discourse and Pragmatics': False,
    'Ethic Concerns:Efficient Methods for NLP': False,
    'Ethic Concerns:Ethics': False,
    'Ethic Concerns:Language Modeling and Analysis of Language Models': False,
    'Ethic Concerns:Linguistic Theories, Cognitive Modeling and Psycholinguistics': False,
    'Ethic Concerns:Multilinguality': False,
    'Ethic Concerns:NLP Applications': False,
    'Ethic Concerns:Resources and Evaluation': False,
    'Ethic Concerns:Sentiment Analysis, Stylistic Analysis, and Argument Mining': False,
    'Ethic Concerns:Speech, Vision, Robotics, Multimodal Grounding': False,
    'Ethic Concerns:Summarization': False,
    'Ethic Concerns:Theme Track': False,
    'Ethic Concerns:Unsupervised and Weakly-Supervised Methods in NLP': False,
    'Ethics': False,
    'Information Extraction': False,
    'Information Retrieval and Text Mining': False,
    'Interpretability, Interactivity and Analysis of Models for NLP': True,
    'Language Modeling and Analysis of Language Models': False,
    'Linguistic Theories, Cognitive Modeling and Psycholinguistics': False,
    'Machine Learning for NLP': False,
    'Machine Translation': False,
    'Multilinguality': False,
    'NLP Applications': False,
    'Natural Language Generation': False,
    'Phonology, Morphology and Word Segmentation': False,
    'Question Answering': False,
    'Resources and Evaluation': False,
    'Semantics: Lexical, Sentence level, Textual Inference and Other areas': False,
    'Sentiment Analysis, Stylistic Analysis, and Argument Mining': False,
    'Speech, Vision, Robotics, Multimodal Grounding': False,
    'Summarization': False,
    'Syntax, Parsing and their Applications': False,
    'Theme Track': False,
    'Unsupervised and Weakly-Supervised Methods in NLP': False
}

df['interpretability'] = df['Track'].apply(lambda x: research_areas_ethics[x])
df
# Out:
#       Submission ID                                              Title  \
# 548             123  Generative Knowledge Graph Construction: A Review
# 549             142  CDConv: A Benchmark for Contradiction Detectio...
# 550             164  Transformer Feed-Forward Layers Build Predicti...
# 551             168  Learning to Generate Question by Asking Questi...
# 552             236  Graph-based Model Generation for Few-Shot Rela...
# ...             ...                                                ...
# 1372           4608  PAR: Political Actor Representation Learning w...
# 1373           4613  JDDC 2.1: A Multimodal Chinese Dialogue Datase...
# 1374           4618  PCL: Peer-Contrastive Learning with Diverse Au...
# 1375           4621  Digging Errors in NMT: Evaluating and Understa...
# 1376           4622  DialogConv: A Lightweight Fully Convolutional ...
#
#      Acceptance Status                                              Track  \
# ...

# %%
new_df = pd.DataFrame()
new_df['id'] = df['Submission ID']
new_df['title'] = df['Title']
new_df['area'] = df['Track']
new_df['interpretability'] = df['interpretability']
new_df['source'] = 'EMNLP2022'

new_df
# Out:
#         id                                              title  \
# 548    123  Generative Knowledge Graph Construction: A Review
# 549    142  CDConv: A Benchmark for Contradiction Detectio...
# 550    164  Transformer Feed-Forward Layers Build Predicti...
# 551    168  Learning to Generate Question by Asking Questi...
# 552    236  Graph-based Model Generation for Few-Shot Rela...
# ...    ...                                                ...
# 1372  4608  PAR: Political Actor Representation Learning w...
# 1373  4613  JDDC 2.1: A Multimodal Chinese Dialogue Datase...
# 1374  4618  PCL: Peer-Contrastive Learning with Diverse Au...
# 1375  4621  Digging Errors in NMT: Evaluating and Understa...
# 1376  4622  DialogConv: A Lightweight Fully Convolutional ...
#
#                                                    area  interpretability  \
# 548                              Information Extraction             False
# ...

# %%
new_df['doi'] = new_df['title'].apply(get_acl_anthology_doi)
new_df
# Out:
#         id                                              title  \
# 548    123  Generative Knowledge Graph Construction: A Review
# 549    142  CDConv: A Benchmark for Contradiction Detectio...
# 550    164  Transformer Feed-Forward Layers Build Predicti...
# 551    168  Learning to Generate Question by Asking Questi...
# 552    236  Graph-based Model Generation for Few-Shot Rela...
# ...    ...                                                ...
# 1372  4608  PAR: Political Actor Representation Learning w...
# 1373  4613  JDDC 2.1: A Multimodal Chinese Dialogue Datase...
# 1374  4618  PCL: Peer-Contrastive Learning with Diverse Au...
# 1375  4621  Digging Errors in NMT: Evaluating and Understa...
# 1376  4622  DialogConv: A Lightweight Fully Convolutional ...
#
#                                                    area  interpretability  \
# 548                              Information Extraction             False
# ...

# %%
# this paper was actually published in EMNLP 2023
new_df = new_df[~(new_df['title'] == 'Federated Meta-Learning for Emotion and Sentiment Aware Multi-modal Complaint Identification')]
new_df
# Out:
#         id                                              title  \
# 548    123  Generative Knowledge Graph Construction: A Review
# 549    142  CDConv: A Benchmark for Contradiction Detectio...
# 550    164  Transformer Feed-Forward Layers Build Predicti...
# 551    168  Learning to Generate Question by Asking Questi...
# 552    236  Graph-based Model Generation for Few-Shot Rela...
# ...    ...                                                ...
# 1372  4608  PAR: Political Actor Representation Learning w...
# 1373  4613  JDDC 2.1: A Multimodal Chinese Dialogue Datase...
# 1374  4618  PCL: Peer-Contrastive Learning with Diverse Au...
# 1375  4621  Digging Errors in NMT: Evaluating and Understa...
# 1376  4622  DialogConv: A Lightweight Fully Convolutional ...
#
#                                                    area  interpretability  \
# 548                              Information Extraction             False
# ...

# %% [markdown]
# # Saving the results

# %%
previous_df = pd.read_csv('../data/parsed_data.csv')
previous_df = previous_df.drop('Unnamed: 0', axis=1)
previous_df
# Out:
#          id                                              title  \
# 0       187  Probabilistic FastText for Multi-Sense Word Em...
# 1      1520  A La Carte Embedding: Cheap but Effective Indu...
# 2       707  Unsupervised Learning of Distributional Relati...
# 3      1553  Explicit Retrofitting of Distributional Word V...
# 4        76  Unsupervised Neural Machine Translation with W...
# ...     ...                                                ...
# 9277  s1835  On Extractive and Abstractive Neural Document ...
# 9278  s2125  Multi-Fact Correction in Abstractive Text Summ...
# 9279  s2506  Evaluating the Factual Consistency of Abstract...
# 9280  s3552     Re-evaluating Evaluation in Text Summarization
# 9281   s702  VMSMO: Learning to Generate Multimodal Summary...
#
#                      area interpretability                              doi  \
# 0          Word Semantics              NaN             10.18653/v1/P18-1001
# ...

# %%
# we'll delete previous rows from the conference
previous_df = previous_df[previous_df['source'] != 'EMNLP2022']
previous_df
# Out:
#          id                                              title  \
# 0       187  Probabilistic FastText for Multi-Sense Word Em...
# 1      1520  A La Carte Embedding: Cheap but Effective Indu...
# 2       707  Unsupervised Learning of Distributional Relati...
# 3      1553  Explicit Retrofitting of Distributional Word V...
# 4        76  Unsupervised Neural Machine Translation with W...
# ...     ...                                                ...
# 9277  s1835  On Extractive and Abstractive Neural Document ...
# 9278  s2125  Multi-Fact Correction in Abstractive Text Summ...
# 9279  s2506  Evaluating the Factual Consistency of Abstract...
# 9280  s3552     Re-evaluating Evaluation in Text Summarization
# 9281   s702  VMSMO: Learning to Generate Multimodal Summary...
#
#                      area interpretability                              doi  \
# 0          Word Semantics              NaN             10.18653/v1/P18-1001
# ...

# %%
updated_df = pd.concat([previous_df, new_df], ignore_index=True)
updated_df
# Out:
#         id                                              title  \
# 0      187  Probabilistic FastText for Multi-Sense Word Em...
# 1     1520  A La Carte Embedding: Cheap but Effective Indu...
# 2      707  Unsupervised Learning of Distributional Relati...
# 3     1553  Explicit Retrofitting of Distributional Word V...
# 4       76  Unsupervised Neural Machine Translation with W...
# ...    ...                                                ...
# 9277  4608  PAR: Political Actor Representation Learning w...
# 9278  4613  JDDC 2.1: A Multimodal Chinese Dialogue Datase...
# 9279  4618  PCL: Peer-Contrastive Learning with Diverse Au...
# 9280  4621  Digging Errors in NMT: Evaluating and Understa...
# 9281  4622  DialogConv: A Lightweight Fully Convolutional ...
#
#                                                    area interpretability  \
# 0                                        Word Semantics              NaN
# ...

# %%
updated_df.to_csv('../data/parsed_data.csv')
