# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))

# %%
from utils import *
import pandas as pd
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
df = pd.read_csv('../data/emnlp2021/emnlp2021.tsv', sep="\t")
df
# Out:
#                                                   Track  \
# 0     Computational Social Science and Cultural Anal...
# 1     Computational Social Science and Cultural Anal...
# 2     Computational Social Science and Cultural Anal...
# 3     Computational Social Science and Cultural Anal...
# 4     Computational Social Science and Cultural Anal...
# ...                                                 ...
# 1254             Syntax: Tagging, Chunking, and Parsing
# 1255             Syntax: Tagging, Chunking, and Parsing
# 1256             Syntax: Tagging, Chunking, and Parsing
# 1257             Syntax: Tagging, Chunking, and Parsing
# 1258             Syntax: Tagging, Chunking, and Parsing
#
#                                                   Title  \
# 0     How Does Counterfactually Augmented Data Impac...
# 1     Mining the Cause of Political Decision-Making ...
# 2     {WHOS}e {H}eritage: {C}lassification of {UNESC...
# 3     To Protect and To Serve? Analyzing Entity-Cent...
# 4     An unsupervised framework for tracing textual ...
# ...                                                 ...
# 1254  On the Relation between Syntactic Divergence a...
# 1255      Revisiting Tri-training of Dependency Parsers
# 1256  Improved Latent Tree Induction with Distant Su...
# 1257  Word Reordering for Zero-shot Cross-lingual St...
# 1258  A Unified Encoding of Structures in Transition...
#
#                                                 Authors Acceptance_Status
# 0     Indira Sen, Mattia Samory, Fabian Flöck, Claud...       Accept-Oral
# 1     Zhijing Jin, Zeyu Peng, Tejas Vaidhya, Bernhar...   Accept-Findings
# 2     Nan Bai, Renqian Luo, Pirouz Nourian and Ana P...   Accept-Findings
# 3                             Caleb Ziems and Diyi Yang   Accept-Findings
# 4     Aida Ramezani, Zining Zhu, Frank Rudzicz and Y...   Accept-Findings
# ...                                                 ...               ...
# 1254  Ofir Arviv, Dmitry Nikolaev, Taelin Karidi and...     Accept-Poster
# 1255                 Joachim Wagner and Jennifer Foster     Accept-Poster
# 1256  Zhiyang Xu, Andrew Drozdov, Jay Yoon Lee, Tim ...     Accept-Poster
# 1257  Tao Ji, Yong Jiang, Tao Wang, Zhongqiang Huang...     Accept-Poster
# 1258  Tao Ji, Yong Jiang, Tao Wang, Zhongqiang Huang...     Accept-Poster
#
# [1259 rows x 4 columns]

# %%
set(df['Track'])
# Out:
# {'Computational Social Science and Cultural Analytics',
#  'Dialog and Interactive Systems',
#  'Discourse and Pragmatics',
#  'Efficient Methods for NLP',
#  'Ethics and NLP',
#  'Generation',
#  'Information Extraction',
#  'Information Retrieval and Text Mining',
#  'Interpretability and Analysis of Models for NLP',
#  'Linguistic Theories, Cognitive Modeling and Psycholinguistics',
#  'Machine Learning for NLP',
#  'Machine Translation and Multilinguality',
#  'Multidisciplinary and Area Chair COI',
#  'NLP Applications',
#  'Phonology, Morphology and Word Segmentation',
#  'Question Answering',
#  'Resources and Evaluation',
#  'Semantics: Lexical, Sentence level, Textual Inference and Other areas',
#  'Sentiment Analysis, Stylistic Analysis, and Argument Mining',
#  'Speech, Vision, Robotics, Multimodal Grounding',
#  'Summarization',
#  'Syntax: Tagging, Chunking, and Parsing'}

# %%
research_areas_to_is_interpretability = {
    'Computational Social Science and Cultural Analytics': False,
    'Dialog and Interactive Systems': False,
    'Discourse and Pragmatics': False,
    'Efficient Methods for NLP': False,
    'Ethics and NLP': False,
    'Generation': False,
    'Information Extraction': False,
    'Information Retrieval and Text Mining': False,
    'Interpretability and Analysis of Models for NLP': True,
    'Linguistic Theories, Cognitive Modeling and Psycholinguistics': False,
    'Machine Learning for NLP': False,
    'Machine Translation and Multilinguality': False,
    'Multidisciplinary and Area Chair COI': False,
    'NLP Applications': False,
    'Phonology, Morphology and Word Segmentation': False,
    'Question Answering': False,
    'Resources and Evaluation': False,
    'Sentiment Analysis, Stylistic Analysis, and Argument Mining': False,
    'Speech, Vision, Robotics, Multimodal Grounding': False,
    'Summarization': False,
    'Syntax: Tagging, Chunking, and Parsing': False,
    'Semantics: Lexical, Sentence level, Textual Inference and Other areas': False
}

df['interpretability'] = df['Track'].apply(lambda x: research_areas_to_is_interpretability[x])

# %%
new_df = pd.DataFrame()
new_df['id'] = None
new_df['title'] = df['Title']
new_df['area'] = df['Track']
new_df['interpretability'] = df['interpretability']
new_df['source'] = 'EMNLP2021'

new_df
# Out:
#        id                                              title  \
# 0     NaN  How Does Counterfactually Augmented Data Impac...
# 1     NaN  Mining the Cause of Political Decision-Making ...
# 2     NaN  {WHOS}e {H}eritage: {C}lassification of {UNESC...
# 3     NaN  To Protect and To Serve? Analyzing Entity-Cent...
# 4     NaN  An unsupervised framework for tracing textual ...
# ...   ...                                                ...
# 1254  NaN  On the Relation between Syntactic Divergence a...
# 1255  NaN      Revisiting Tri-training of Dependency Parsers
# 1256  NaN  Improved Latent Tree Induction with Distant Su...
# 1257  NaN  Word Reordering for Zero-shot Cross-lingual St...
# 1258  NaN  A Unified Encoding of Structures in Transition...
#
#                                                    area  interpretability  \
# 0     Computational Social Science and Cultural Anal...             False
# 1     Computational Social Science and Cultural Anal...             False
# 2     Computational Social Science and Cultural Anal...             False
# 3     Computational Social Science and Cultural Anal...             False
# 4     Computational Social Science and Cultural Anal...             False
# ...                                                 ...               ...
# 1254             Syntax: Tagging, Chunking, and Parsing             False
# 1255             Syntax: Tagging, Chunking, and Parsing             False
# 1256             Syntax: Tagging, Chunking, and Parsing             False
# 1257             Syntax: Tagging, Chunking, and Parsing             False
# 1258             Syntax: Tagging, Chunking, and Parsing             False
#
#          source
# 0     EMNLP2021
# 1     EMNLP2021
# 2     EMNLP2021
# 3     EMNLP2021
# 4     EMNLP2021
# ...         ...
# 1254  EMNLP2021
# 1255  EMNLP2021
# 1256  EMNLP2021
# 1257  EMNLP2021
# 1258  EMNLP2021
#
# [1259 rows x 5 columns]

# %%
new_df['doi'] = new_df['title'].apply(get_acl_anthology_doi)
new_df
# Out:
#        id                                              title  \
# 0     NaN  How Does Counterfactually Augmented Data Impac...
# 1     NaN  Mining the Cause of Political Decision-Making ...
# 2     NaN  {WHOS}e {H}eritage: {C}lassification of {UNESC...
# 3     NaN  To Protect and To Serve? Analyzing Entity-Cent...
# 4     NaN  An unsupervised framework for tracing textual ...
# ...   ...                                                ...
# 1254  NaN  On the Relation between Syntactic Divergence a...
# 1255  NaN      Revisiting Tri-training of Dependency Parsers
# 1256  NaN  Improved Latent Tree Induction with Distant Su...
# 1257  NaN  Word Reordering for Zero-shot Cross-lingual St...
# 1258  NaN  A Unified Encoding of Structures in Transition...
#
#                                                    area  interpretability  \
# 0     Computational Social Science and Cultural Anal...             False
# 1     Computational Social Science and Cultural Anal...             False
# 2     Computational Social Science and Cultural Anal...             False
# 3     Computational Social Science and Cultural Anal...             False
# 4     Computational Social Science and Cultural Anal...             False
# ...                                                 ...               ...
# 1254             Syntax: Tagging, Chunking, and Parsing             False
# 1255             Syntax: Tagging, Chunking, and Parsing             False
# 1256             Syntax: Tagging, Chunking, and Parsing             False
# 1257             Syntax: Tagging, Chunking, and Parsing             False
# 1258             Syntax: Tagging, Chunking, and Parsing             False
#
#          source                                  doi
# 0     EMNLP2021       10.18653/v1/2021.emnlp-main.28
# 1     EMNLP2021   10.18653/v1/2021.findings-emnlp.27
# 2     EMNLP2021                                 None
# 3     EMNLP2021   10.18653/v1/2021.findings-emnlp.82
# 4     EMNLP2021  10.18653/v1/2021.findings-emnlp.105
# ...         ...                                  ...
# 1254  EMNLP2021      10.18653/v1/2021.emnlp-main.394
# 1255  EMNLP2021      10.18653/v1/2021.emnlp-main.745
# 1256  EMNLP2021      10.18653/v1/2021.emnlp-main.395
# 1257  EMNLP2021      10.18653/v1/2021.emnlp-main.338
# 1258  EMNLP2021      10.18653/v1/2021.emnlp-main.339
#
# [1259 rows x 6 columns]

# %%
previous_df = pd.read_csv('../data/parsed_data.csv')
previous_df = previous_df.drop('Unnamed: 0', axis=1)

previous_df
# Out:
#          id                                              title  \
# 0       797  Restricted Recurrent Neural Tensor Networks: E...
# 1       338  Neural Hidden Markov Model for Machine Transla...
# 2       300  Attention Focusing for Neural Machine Translat...
# 3      1638  Will it Blend? Blending Weak and Strong Labele...
# 4        92  Batch IS NOT Heavy: Learning Word Representati...
# ...     ...                                                ...
# 10190   NaN  On the Relation between Syntactic Divergence a...
# 10191   NaN      Revisiting Tri-training of Dependency Parsers
# 10192   NaN  Improved Latent Tree Induction with Distant Su...
# 10193   NaN  Word Reordering for Zero-shot Cross-lingual St...
# 10194   NaN  A Unified Encoding of Structures in Transition...
#
#                                          area interpretability  \
# 0                                         NaN              NaN
# 1                                         NaN              NaN
# 2                                         NaN              NaN
# 3                                         NaN              NaN
# 4                                         NaN              NaN
# ...                                       ...              ...
# 10190  Syntax: Tagging, Chunking, and Parsing            False
# 10191  Syntax: Tagging, Chunking, and Parsing            False
# 10192  Syntax: Tagging, Chunking, and Parsing            False
# 10193  Syntax: Tagging, Chunking, and Parsing            False
# 10194  Syntax: Tagging, Chunking, and Parsing            False
#
#                         doi     source
# 0      10.18653/v1/P18-2002    ACL2019
# 1      10.18653/v1/P18-2060    ACL2019
# 2      10.18653/v1/P18-1164    ACL2019
# 3      10.18653/v1/P18-2095    ACL2019
# 4      10.18653/v1/P18-1172    ACL2019
# ...                     ...        ...
# 10190                   NaN  EMNLP2021
# 10191                   NaN  EMNLP2021
# 10192                   NaN  EMNLP2021
# 10193                   NaN  EMNLP2021
# 10194                   NaN  EMNLP2021
#
# [10195 rows x 6 columns]

# %%
previous_df = previous_df[previous_df['source'] != 'EMNLP2021']
previous_df
# Out:
#         id                                              title  \
# 0      797  Restricted Recurrent Neural Tensor Networks: E...
# 1      338  Neural Hidden Markov Model for Machine Transla...
# 2      300  Attention Focusing for Neural Machine Translat...
# 3     1638  Will it Blend? Blending Weak and Strong Labele...
# 4       92  Batch IS NOT Heavy: Learning Word Representati...
# ...    ...                                                ...
# 8931  1125  Know What You Don’t Know: Unanswerable Questio...
# 8932  1603  ‘Lighter’ Can Still Be Dark: Modeling Comparat...
# 8933   618  Finding syntax in human encephalography with b...
# 8934  1247  Learning to Ask Good Questions: Ranking Clarif...
# 8935  1348  Let’s do it “again”: A First Computational App...
#
#                     area interpretability                   doi   source
# 0                    NaN              NaN  10.18653/v1/P18-2002  ACL2019
# 1                    NaN              NaN  10.18653/v1/P18-2060  ACL2019
# 2                    NaN              NaN  10.18653/v1/P18-1164  ACL2019
# 3                    NaN              NaN  10.18653/v1/P18-2095  ACL2019
# 4                    NaN              NaN  10.18653/v1/P18-1172  ACL2019
# ...                  ...              ...                   ...      ...
# 8931  Best Paper Session              NaN  10.18653/v1/P18-2124  ACL2018
# 8932  Best Paper Session              NaN  10.18653/v1/P18-2125  ACL2018
# 8933  Best Paper Session              NaN  10.18653/v1/P18-1254  ACL2018
# 8934  Best Paper Session              NaN  10.18653/v1/P18-1255  ACL2018
# 8935  Best Paper Session              NaN  10.18653/v1/P18-1256  ACL2018
#
# [8936 rows x 6 columns]

# %%
updated_df = pd.concat([previous_df, new_df], ignore_index=True)
updated_df
# Out:
#          id                                              title  \
# 0       797  Restricted Recurrent Neural Tensor Networks: E...
# 1       338  Neural Hidden Markov Model for Machine Transla...
# 2       300  Attention Focusing for Neural Machine Translat...
# 3      1638  Will it Blend? Blending Weak and Strong Labele...
# 4        92  Batch IS NOT Heavy: Learning Word Representati...
# ...     ...                                                ...
# 10190   NaN  On the Relation between Syntactic Divergence a...
# 10191   NaN      Revisiting Tri-training of Dependency Parsers
# 10192   NaN  Improved Latent Tree Induction with Distant Su...
# 10193   NaN  Word Reordering for Zero-shot Cross-lingual St...
# 10194   NaN  A Unified Encoding of Structures in Transition...
#
#                                          area interpretability  \
# 0                                         NaN              NaN
# 1                                         NaN              NaN
# 2                                         NaN              NaN
# 3                                         NaN              NaN
# 4                                         NaN              NaN
# ...                                       ...              ...
# 10190  Syntax: Tagging, Chunking, and Parsing            False
# 10191  Syntax: Tagging, Chunking, and Parsing            False
# 10192  Syntax: Tagging, Chunking, and Parsing            False
# 10193  Syntax: Tagging, Chunking, and Parsing            False
# 10194  Syntax: Tagging, Chunking, and Parsing            False
#
#                                    doi     source
# 0                 10.18653/v1/P18-2002    ACL2019
# 1                 10.18653/v1/P18-2060    ACL2019
# 2                 10.18653/v1/P18-1164    ACL2019
# 3                 10.18653/v1/P18-2095    ACL2019
# 4                 10.18653/v1/P18-1172    ACL2019
# ...                                ...        ...
# 10190  10.18653/v1/2021.emnlp-main.394  EMNLP2021
# 10191  10.18653/v1/2021.emnlp-main.745  EMNLP2021
# 10192  10.18653/v1/2021.emnlp-main.395  EMNLP2021
# 10193  10.18653/v1/2021.emnlp-main.338  EMNLP2021
# 10194  10.18653/v1/2021.emnlp-main.339  EMNLP2021
#
# [10195 rows x 6 columns]

# %%
updated_df.to_csv('../data/parsed_data.csv')
