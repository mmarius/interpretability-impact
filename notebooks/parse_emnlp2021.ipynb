# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))

# %%
from utils import *

import pandas as pd
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
df = pd.read_csv('../data/emnlp2021/emnlp2021.tsv', sep="\t")
df
# Out:
#                                                   Track  \
# 0     Computational Social Science and Cultural Anal...
# 1     Computational Social Science and Cultural Anal...
# 2     Computational Social Science and Cultural Anal...
# 3     Computational Social Science and Cultural Anal...
# 4     Computational Social Science and Cultural Anal...
# ...                                                 ...
# 1035             Syntax: Tagging, Chunking, and Parsing
# 1036             Syntax: Tagging, Chunking, and Parsing
# 1037             Syntax: Tagging, Chunking, and Parsing
# 1038             Syntax: Tagging, Chunking, and Parsing
# 1039             Syntax: Tagging, Chunking, and Parsing
#
#                                                   Title  \
# 0     How Does Counterfactually Augmented Data Impac...
# 1     Mining the Cause of Political Decision-Making ...
# 2     {WHOS}e {H}eritage: {C}lassification of {UNESC...
# 3     To Protect and To Serve? Analyzing Entity-Cent...
# 4     An unsupervised framework for tracing textual ...
# ...                                                 ...
# 1035  On the Relation between Syntactic Divergence a...
# 1036      Revisiting Tri-training of Dependency Parsers
# 1037  Improved Latent Tree Induction with Distant Su...
# 1038  Word Reordering for Zero-shot Cross-lingual St...
# 1039  A Unified Encoding of Structures in Transition...
#
#                                                 Authors Acceptance_Status
# 0     Indira Sen, Mattia Samory, Fabian Flöck, Claud...       Accept-Oral
# 1     Zhijing Jin, Zeyu Peng, Tejas Vaidhya, Bernhar...   Accept-Findings
# 2     Nan Bai, Renqian Luo, Pirouz Nourian and Ana P...   Accept-Findings
# 3                             Caleb Ziems and Diyi Yang   Accept-Findings
# 4     Aida Ramezani, Zining Zhu, Frank Rudzicz and Y...   Accept-Findings
# ...                                                 ...               ...
# 1035  Ofir Arviv, Dmitry Nikolaev, Taelin Karidi and...     Accept-Poster
# 1036                 Joachim Wagner and Jennifer Foster     Accept-Poster
# 1037  Zhiyang Xu, Andrew Drozdov, Jay Yoon Lee, Tim ...     Accept-Poster
# 1038  Tao Ji, Yong Jiang, Tao Wang, Zhongqiang Huang...     Accept-Poster
# 1039  Tao Ji, Yong Jiang, Tao Wang, Zhongqiang Huang...     Accept-Poster
#
# [1040 rows x 4 columns]

# %%
set(df['Track'])
# Out:
# {'Computational Social Science and Cultural Analytics',
#  'Dialog and Interactive Systems',
#  'Discourse and Pragmatics',
#  'Efficient Methods for NLP',
#  'Ethics and NLP',
#  'Generation',
#  'Information Extraction',
#  'Information Retrieval and Text Mining',
#  'Interpretability and Analysis of Models for NLP',
#  'Linguistic Theories, Cognitive Modeling and Psycholinguistics',
#  'Machine Learning for NLP',
#  'Machine Translation and Multilinguality',
#  'Multidisciplinary and Area Chair COI',
#  'NLP Applications',
#  'Phonology, Morphology and Word Segmentation',
#  'Question Answering',
#  'Resources and Evaluation',
#  'Sentiment Analysis, Stylistic Analysis, and Argument Mining',
#  'Speech, Vision, Robotics, Multimodal Grounding',
#  'Summarization',
#  'Syntax: Tagging, Chunking, and Parsing'}

# %%
research_areas_to_is_interpretability = {
    'Computational Social Science and Cultural Analytics': False,
    'Dialog and Interactive Systems': False,
    'Discourse and Pragmatics': False,
    'Efficient Methods for NLP': False,
    'Ethics and NLP': False,
    'Generation': False,
    'Information Extraction': False,
    'Information Retrieval and Text Mining': False,
    'Interpretability and Analysis of Models for NLP': True,
    'Linguistic Theories, Cognitive Modeling and Psycholinguistics': False,
    'Machine Learning for NLP': False,
    'Machine Translation and Multilinguality': False,
    'Multidisciplinary and Area Chair COI': False,
    'NLP Applications': False,
    'Phonology, Morphology and Word Segmentation': False,
    'Question Answering': False,
    'Resources and Evaluation': False,
    'Sentiment Analysis, Stylistic Analysis, and Argument Mining': False,
    'Speech, Vision, Robotics, Multimodal Grounding': False,
    'Summarization': False,
    'Syntax: Tagging, Chunking, and Parsing': False
}

df['interpretability'] = df['Track'].apply(lambda x: research_areas_to_is_interpretability[x])
# Out:
#                                                Track  \
# 396  Interpretability and Analysis of Models for NLP
# 397  Interpretability and Analysis of Models for NLP
# 398  Interpretability and Analysis of Models for NLP
# 399  Interpretability and Analysis of Models for NLP
# 400  Interpretability and Analysis of Models for NLP
# ..                                               ...
# 452  Interpretability and Analysis of Models for NLP
# 453  Interpretability and Analysis of Models for NLP
# 454  Interpretability and Analysis of Models for NLP
# 455  Interpretability and Analysis of Models for NLP
# 456  Interpretability and Analysis of Models for NLP
#
#                                                  Title  \
# 396  Attention Weights in Transformer NMT Fail Alig...
# 397  Rethinking Why Intermediate-Task Fine-Tuning W...
# 398  Probing Across Time: What Does RoBERTa Know an...
# 399  Task-adaptive Pre-training and Self-training a...
# 400  Is BERT a Cross-Disciplinary Knowledge Learner...
# ..                                                 ...
# 452           Lifelong Explainer for Lifelong Learners
# 453  On the Transferability of Adversarial Attacks ...
# 454  Conditional probing: measuring usable informat...
# 455  Contrasting Human- and Machine-Generated Word-...
# 456  FastIF: Scalable Influence Functions for Effic...
#
#                                                Authors Acceptance_Status  \
# 396           Javier Ferrando and Marta R. Costa-jussà   Accept-Findings
# 397                      Ting-Yun Chang and Chi-Jen Lu   Accept-Findings
# 398  Zeyu Liu, Yizhong Wang, Jungo Kasai, Hannaneh ...   Accept-Findings
# 399  Shiyang Li, Semih Yavuz, Wenhu Chen and Xifeng...   Accept-Findings
# 400                      Wei-Tsung Kao and Hung-yi Lee   Accept-Findings
# ..                                                 ...               ...
# 452  Xuelin Situ, Sameen Maruf, Ingrid Zukerman, Ce...     Accept-Poster
# 453  Liping Yuan, Xiaoqing Zheng, Yi Zhou, Cho-Jui ...     Accept-Poster
# 454  John Hewitt, Kawin Ethayarajh, Percy Liang and...     Accept-Poster
# 455  Maximilian Mozes, Max Bartolo, Pontus Stenetor...     Accept-Poster
# 456  Han Guo, Nazneen Fatema Rajani, Peter Hase, Mo...       Accept-Oral
#
#      interpretability
# 396              True
# 397              True
# 398              True
# 399              True
# 400              True
# ..                ...
# 452              True
# 453              True
# 454              True
# 455              True
# 456              True
#
# [61 rows x 5 columns]

# %%
new_df = pd.DataFrame()
new_df['id'] = None
new_df['title'] = df['Title']
new_df['area'] = df['Track']
new_df['interpretability'] = df['interpretability']
new_df['source'] = 'EMNLP2021'

new_df
# Out:
#        id                                              title  \
# 0     NaN  How Does Counterfactually Augmented Data Impac...
# 1     NaN  Mining the Cause of Political Decision-Making ...
# 2     NaN  {WHOS}e {H}eritage: {C}lassification of {UNESC...
# 3     NaN  To Protect and To Serve? Analyzing Entity-Cent...
# 4     NaN  An unsupervised framework for tracing textual ...
# ...   ...                                                ...
# 1035  NaN  On the Relation between Syntactic Divergence a...
# 1036  NaN      Revisiting Tri-training of Dependency Parsers
# 1037  NaN  Improved Latent Tree Induction with Distant Su...
# 1038  NaN  Word Reordering for Zero-shot Cross-lingual St...
# 1039  NaN  A Unified Encoding of Structures in Transition...
#
#                                                    area  interpretability  \
# 0     Computational Social Science and Cultural Anal...             False
# 1     Computational Social Science and Cultural Anal...             False
# 2     Computational Social Science and Cultural Anal...             False
# 3     Computational Social Science and Cultural Anal...             False
# 4     Computational Social Science and Cultural Anal...             False
# ...                                                 ...               ...
# 1035             Syntax: Tagging, Chunking, and Parsing             False
# 1036             Syntax: Tagging, Chunking, and Parsing             False
# 1037             Syntax: Tagging, Chunking, and Parsing             False
# 1038             Syntax: Tagging, Chunking, and Parsing             False
# 1039             Syntax: Tagging, Chunking, and Parsing             False
#
#          source
# 0     EMNLP2021
# 1     EMNLP2021
# 2     EMNLP2021
# 3     EMNLP2021
# 4     EMNLP2021
# ...         ...
# 1035  EMNLP2021
# 1036  EMNLP2021
# 1037  EMNLP2021
# 1038  EMNLP2021
# 1039  EMNLP2021
#
# [1040 rows x 5 columns]
