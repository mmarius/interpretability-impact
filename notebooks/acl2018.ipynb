# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))
from utils import *
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
url = 'https://acl2018.org/programme/schedule/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
papers = []
day_schedules = soup.find_all(class_='day-program')
for day in day_schedules:
    rows = day.find_all('tr')
    current_titles = []
    for row in rows:
        is_area_track_info_row = 'session-name-row' in row['class'] and 'conc-session-indiv-row' in row['class']
        is_orals_papers_row = 'conc-session-details-row' in row['class']
        is_poster_papers_row = 'poster-session-row' in row['class'] and len(list(row.children)) > 1
        if is_area_track_info_row:
            title_divs = row.find_all(class_='conc-session-name')
            title_regex = r'Session \d+[A-Za-z]*: (.*?)\s*\d*$'
            current_titles = [re.search(title_regex, div.text).group(1) for div in title_divs]
        elif is_orals_papers_row:
            papers_per_area = row.find_all('td')
            assert len(papers_per_area) == len(current_titles)
            for paper_column, area in zip(papers_per_area, current_titles):
                for paper_div in paper_column.find_all('div', class_='talk-title'):
                    paper_link_index = 2
                    links = paper_div.find_all('a')
                    paper_link = links[paper_link_index]
                    paper_id = paper_link['href'].split('/')[-1]
                    title = paper_link.text
                    papers.append({'id': paper_id, 'title': title, 'area': area})
            current_titles = []
        elif is_poster_papers_row:
            poster_subsessions = row.find_all(class_='poster-sub-session')
            for subsession in poster_subsessions:
                raw_track_title = subsession.find(class_='poster-session-name').text
                if raw_track_title == 'Tutorial':
                    continue
                title_regex = r'Poster Session \d+[A-Za-z]*: (.*?)$'
                track = re.search(title_regex, raw_track_title).group(1)
                for paper_span in subsession.find_all('span'):
                    links = paper_span.find_all('a')
                    paper_link_index = 1
                    paper_link = links[paper_link_index]
                    paper_id = paper_link['href'].split('/')[-1]
                    title = paper_link.text
                    papers.append({'id': paper_id, 'title': title, 'area': track})
 
df = pd.DataFrame(papers)
df
# Out:
#        id                                              title  \
# 0     187  Probabilistic FastText for Multi-Sense Word Em...
# 1    1520  A La Carte Embedding: Cheap but Effective Indu...
# 2     707  Unsupervised Learning of Distributional Relati...
# 3    1553  Explicit Retrofitting of Distributional Word V...
# 4      76  Unsupervised Neural Machine Translation with W...
# ..    ...                                                ...
# 442  1125  Know What You Don’t Know: Unanswerable Questio...
# 443  1603  'Lighter' Can Still Be Dark: Modeling Comparat...
# 444   618  Finding syntax in human encephalography with b...
# 445  1247  Learning to Ask Good Questions: Ranking Clarif...
# 446  1348  Let's do it ``again'': A First Computational A...
#
#                     area
# 0         Word Semantics
# 1         Word Semantics
# 2         Word Semantics
# 3         Word Semantics
# 4    Machine Translation
# ..                   ...
# 442   Best Paper Session
# 443   Best Paper Session
# 444   Best Paper Session
# 445   Best Paper Session
# 446   Best Paper Session
#
# [447 rows x 3 columns]

# %%
# there is no interpretability area, so we are not sure which area these papers might be sent to
areas = set(list(df['area']))
areas
# Out:
# {'Argument Mining',
#  'Best Paper Session',
#  'Dialog System',
#  'Dialog System, Discourse',
#  'Dialog and Interactive Systems, Multilinguality',
#  'Discourse',
#  'Discourse, Linguistics, Cognitive Modeling',
#  'Document Analysis',
#  'Evaluation',
#  'Generation',
#  'Generation, Summarization',
#  'Inference, Reasoning',
#  'Information Extraction',
#  'Information Extraction, Text Mining',
#  'Information Retrieval',
#  'Language/Document Model',
#  'Linguistics, Psycholinguistics and Cognitive Modeling',
#  'Machine Learning',
#  'Machine Learning, Question Answering',
#  'Machine Translation',
#  'Machine Translation, Multilinguality',
#  'Morphology, Tagging, Parsing',
#  'Multilinguality',
#  'Multimodal',
#  'Parsing',
#  'Parsing, Morphology',
#  'Question Answering',
#  'Resource, Annotation',
#  'Resources and Evaluation',
#  'Semantic Parsing',
#  'Semantics',
#  'Sentiment',
#  'Sentiment Analysis and Argument Mining',
#  'Social Media',
#  'Student Research Workshop',
#  'Summarization',
#  'Summarization, Social Media',
#  'System Demonstrations',
#  'Text Mining and Applications',
#  'Vision',
#  'Vision, Linguistics, Resource and Evaluation',
#  'Vision, Multimodal, Grounding, Speech',
#  'Word Semantics'}

# %%
NON_MAIN_CONFERENCE_AREAS = ['Student Research Workshop', 'System Demonstrations']

df = df[~df['area'].isin(NON_MAIN_CONFERENCE_AREAS)].copy()
df
# Out:
#        id                                              title  \
# 0     187  Probabilistic FastText for Multi-Sense Word Em...
# 1    1520  A La Carte Embedding: Cheap but Effective Indu...
# 2     707  Unsupervised Learning of Distributional Relati...
# 3    1553  Explicit Retrofitting of Distributional Word V...
# 4      76  Unsupervised Neural Machine Translation with W...
# ..    ...                                                ...
# 442  1125  Know What You Don’t Know: Unanswerable Questio...
# 443  1603  'Lighter' Can Still Be Dark: Modeling Comparat...
# 444   618  Finding syntax in human encephalography with b...
# 445  1247  Learning to Ask Good Questions: Ranking Clarif...
# 446  1348  Let's do it ``again'': A First Computational A...
#
#                     area
# 0         Word Semantics
# 1         Word Semantics
# 2         Word Semantics
# 3         Word Semantics
# 4    Machine Translation
# ..                   ...
# 442   Best Paper Session
# 443   Best Paper Session
# 444   Best Paper Session
# 445   Best Paper Session
# 446   Best Paper Session
#
# [401 rows x 3 columns]

# %%
df['source'] = 'ACL'
df['year'] = 2018
df['doi'] = None
df['abstract'] = None
df
# Out:
#        id                                              title  \
# 0     187  Probabilistic FastText for Multi-Sense Word Em...
# 1    1520  A La Carte Embedding: Cheap but Effective Indu...
# 2     707  Unsupervised Learning of Distributional Relati...
# 3    1553  Explicit Retrofitting of Distributional Word V...
# 4      76  Unsupervised Neural Machine Translation with W...
# ..    ...                                                ...
# 442  1125  Know What You Don’t Know: Unanswerable Questio...
# 443  1603  'Lighter' Can Still Be Dark: Modeling Comparat...
# 444   618  Finding syntax in human encephalography with b...
# 445  1247  Learning to Ask Good Questions: Ranking Clarif...
# 446  1348  Let's do it ``again'': A First Computational A...
#
#                     area source  year   doi abstract
# 0         Word Semantics    ACL  2018  None     None
# 1         Word Semantics    ACL  2018  None     None
# 2         Word Semantics    ACL  2018  None     None
# 3         Word Semantics    ACL  2018  None     None
# 4    Machine Translation    ACL  2018  None     None
# ..                   ...    ...   ...   ...      ...
# 442   Best Paper Session    ACL  2018  None     None
# 443   Best Paper Session    ACL  2018  None     None
# 444   Best Paper Session    ACL  2018  None     None
# 445   Best Paper Session    ACL  2018  None     None
# 446   Best Paper Session    ACL  2018  None     None
#
# [401 rows x 7 columns]

# %% [markdown]
#  # Saving the results

# %%
previous_df = pd.read_csv('../data/cl_papers.csv', index_col=0)
previous_df
# Out:
#              id                                              title  \
# 0     main.1004  AnswerFact: Fact Checking in Product Question ...
# 1     main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2     main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3     main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4     main.1011  Knowledge Association with Hyperbolic Knowledg...
# ...         ...                                                ...
# 7433        204  The importance of Being Recurrent for Modeling...
# 7434       1198  Towards Dynamic Computation Graphs via Sparse ...
# 7435       1111  Convolutional Neural Networks with Recurrent N...
# 7436  1379-TACL  Language Modeling for Morphologically Rich Lan...
# 7437  1396-TACL  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                   area source  year  \
# 0                   Question Answering  EMNLP  2020
# 1       Dialog and Interactive Systems  EMNLP  2020
# 2       Dialog and Interactive Systems  EMNLP  2020
# 3                     NLP Applications  EMNLP  2020
# 4               Information Extraction  EMNLP  2020
# ...                                ...    ...   ...
# 7433  Area H (Machine Learning) [LONG]  EMNLP  2018
# 7434  Area H (Machine Learning) [LONG]  EMNLP  2018
# 7435  Area H (Machine Learning) [LONG]  EMNLP  2018
# 7436                       Area H or D  EMNLP  2018
# 7437                       Area H or D  EMNLP  2018
#
#                                    doi  \
# 0     10.18653/v1/2020.emnlp-main.1004
# 1     10.18653/v1/2020.emnlp-main.1006
# 2     10.18653/v1/2020.emnlp-main.1009
# 3     10.18653/v1/2020.emnlp-main.1010
# 4     10.18653/v1/2020.emnlp-main.1011
# ...                                ...
# 7433                               NaN
# 7434                               NaN
# 7435                               NaN
# 7436                               NaN
# 7437                               NaN
#
#                                                abstract
# 0     Product-related question answering platforms n...
# 1     We study knowledge-grounded dialogue generatio...
# 2     Video-grounded dialogues are very challenging ...
# 3     With the advancements in natural language proc...
# 4     Capturing associations for knowledge graphs (K...
# ...                                                 ...
# 7433                                                NaN
# 7434                                                NaN
# 7435                                                NaN
# 7436                                                NaN
# 7437                                                NaN
#
# [7438 rows x 7 columns]

# %%
# we'll delete previous rows from the conference
previous_df = previous_df[~((previous_df['source'] == 'ACL') & (previous_df['year'] == 2018))]
previous_df
# Out:
#              id                                              title  \
# 0     main.1004  AnswerFact: Fact Checking in Product Question ...
# 1     main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2     main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3     main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4     main.1011  Knowledge Association with Hyperbolic Knowledg...
# ...         ...                                                ...
# 7433        204  The importance of Being Recurrent for Modeling...
# 7434       1198  Towards Dynamic Computation Graphs via Sparse ...
# 7435       1111  Convolutional Neural Networks with Recurrent N...
# 7436  1379-TACL  Language Modeling for Morphologically Rich Lan...
# 7437  1396-TACL  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                   area source  year  \
# 0                   Question Answering  EMNLP  2020
# 1       Dialog and Interactive Systems  EMNLP  2020
# 2       Dialog and Interactive Systems  EMNLP  2020
# 3                     NLP Applications  EMNLP  2020
# 4               Information Extraction  EMNLP  2020
# ...                                ...    ...   ...
# 7433  Area H (Machine Learning) [LONG]  EMNLP  2018
# 7434  Area H (Machine Learning) [LONG]  EMNLP  2018
# 7435  Area H (Machine Learning) [LONG]  EMNLP  2018
# 7436                       Area H or D  EMNLP  2018
# 7437                       Area H or D  EMNLP  2018
#
#                                    doi  \
# 0     10.18653/v1/2020.emnlp-main.1004
# 1     10.18653/v1/2020.emnlp-main.1006
# 2     10.18653/v1/2020.emnlp-main.1009
# 3     10.18653/v1/2020.emnlp-main.1010
# 4     10.18653/v1/2020.emnlp-main.1011
# ...                                ...
# 7433                               NaN
# 7434                               NaN
# 7435                               NaN
# 7436                               NaN
# 7437                               NaN
#
#                                                abstract
# 0     Product-related question answering platforms n...
# 1     We study knowledge-grounded dialogue generatio...
# 2     Video-grounded dialogues are very challenging ...
# 3     With the advancements in natural language proc...
# 4     Capturing associations for knowledge graphs (K...
# ...                                                 ...
# 7433                                                NaN
# 7434                                                NaN
# 7435                                                NaN
# 7436                                                NaN
# 7437                                                NaN
#
# [7438 rows x 7 columns]

# %%
updated_df = pd.concat([previous_df, df], ignore_index=True)
updated_df
# Out:
#              id                                              title  \
# 0     main.1004  AnswerFact: Fact Checking in Product Question ...
# 1     main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2     main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3     main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4     main.1011  Knowledge Association with Hyperbolic Knowledg...
# ...         ...                                                ...
# 7834       1125  Know What You Don’t Know: Unanswerable Questio...
# 7835       1603  'Lighter' Can Still Be Dark: Modeling Comparat...
# 7836        618  Finding syntax in human encephalography with b...
# 7837       1247  Learning to Ask Good Questions: Ranking Clarif...
# 7838       1348  Let's do it ``again'': A First Computational A...
#
#                                 area source  year  \
# 0                 Question Answering  EMNLP  2020
# 1     Dialog and Interactive Systems  EMNLP  2020
# 2     Dialog and Interactive Systems  EMNLP  2020
# 3                   NLP Applications  EMNLP  2020
# 4             Information Extraction  EMNLP  2020
# ...                              ...    ...   ...
# 7834              Best Paper Session    ACL  2018
# 7835              Best Paper Session    ACL  2018
# 7836              Best Paper Session    ACL  2018
# 7837              Best Paper Session    ACL  2018
# 7838              Best Paper Session    ACL  2018
#
#                                    doi  \
# 0     10.18653/v1/2020.emnlp-main.1004
# 1     10.18653/v1/2020.emnlp-main.1006
# 2     10.18653/v1/2020.emnlp-main.1009
# 3     10.18653/v1/2020.emnlp-main.1010
# 4     10.18653/v1/2020.emnlp-main.1011
# ...                                ...
# 7834                              None
# 7835                              None
# 7836                              None
# 7837                              None
# 7838                              None
#
#                                                abstract
# 0     Product-related question answering platforms n...
# 1     We study knowledge-grounded dialogue generatio...
# 2     Video-grounded dialogues are very challenging ...
# 3     With the advancements in natural language proc...
# 4     Capturing associations for knowledge graphs (K...
# ...                                                 ...
# 7834                                               None
# 7835                                               None
# 7836                                               None
# 7837                                               None
# 7838                                               None
#
# [7839 rows x 7 columns]

# %%
updated_df.to_csv('../data/cl_papers.csv')
