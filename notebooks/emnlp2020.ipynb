# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))
from utils import *

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/acl-org/emnlp-2020-virtual-conference/master/sitedata/main_papers.csv'
df = pd.read_csv(url)
print(df.head())
# Out:
#          UID                                              title  \
# 0  main.1004  AnswerFact: Fact Checking in Product Question ...
# 1  main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2  main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3  main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4  main.1011  Knowledge Association with Hyperbolic Knowledg...
#
#                                              authors  \
# 0            Wenxuan Zhang|Yang Deng|Jing Ma|Wai Lam
# 1  Xueliang Zhao|Wei Wu|Can Xu|Chongyang Tao|Dong...
# 2     Hung Le|Doyen Sahoo|Nancy Chen|Steven C.H. Hoi
# 3       Qinzhuo Wu|Qi Zhang|Jinlan Fu|Xuanjing Huang
# 4  Zequn Sun|Muhao Chen|Wei Hu|Chengming Wang|Jia...
#
#                                             abstract  \
# 0  Product-related question answering platforms n...
# 1  We study knowledge-grounded dialogue generatio...
# 2  Video-grounded dialogues are very challenging ...
# ...

# %%
df['doi'] = None
df['area'] = df['track']
df['id'] = df['UID']
df['source'] = 'EMNLP'
df['year'] = 2020
columns_to_keep = ['id', 'title', 'area', 'source', 'year', 'doi', 'abstract']
clean_df = df[columns_to_keep]
clean_df
# Out:
#             id                                              title  \
# 0    main.1004  AnswerFact: Fact Checking in Product Question ...
# 1    main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2    main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3    main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4    main.1011  Knowledge Association with Hyperbolic Knowledg...
# ..         ...                                                ...
# 776  TACL.2169                                     A* Beam Search
# 777  TACL.2221  Consistent Transcription and Translation of Sp...
# 778  TACL.2255  PERL: Pivot-based Domain Adaptation for Pre-tr...
# 779  TACL.2389  Improving Dialog Evaluation with a Multi-refer...
# 780  TACL.2411  Syntactic Structure Distillation Pretraining f...
#
#                                        area source  year  \
# 0                        Question Answering  EMNLP  2020
# ...

# %%
clean_df['area'].value_counts()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# area
# Machine Learning for NLP                                                  77
# Machine Translation and Multilinguality                                   76
# NLP Applications                                                          66
# Dialog and Interactive Systems                                            62
# Semantics: Sentence-level Semantics, Textual Inference and Other areas    58
# Information Extraction                                                    58
# Interpretability and Analysis of Models for NLP                           54
# Language Generation                                                       49
# Question Answering                                                        42
# Summarization                                                             31
# ...

# %%
clean_df[clean_df['area'] == 'Interpretability and Analysis of Models for NLP']
# Out:
#             id                                              title  \
# 14   main.1052  Asking without Telling: Exploring Latent Ontol...
# 43   main.1205  Top-Rank-Focused Adaptive Vote Collection for ...
# 62   main.1280  Pretrained Language Model Embryology: The Birt...
# 87   main.1428  Improving Low Compute Language Modeling with I...
# 119  main.1551  Pareto Probing: Trading Off Accuracy for Compl...
# 136  main.1612  Interpretation of NLP models through input mar...
# 137  main.1613  Learning Music Helps You Read: Using Transfer ...
# 138  main.1614  Generating Label Cohesive and Well-Formed Adve...
# 144  main.1626  Hate-Speech and Offensive Language Detection i...
# 145  main.1631  An Empirical Investigation Towards Efficient M...
# 197  main.1901        Are All Good Word Vector Spaces Isomorphic?
# 211  main.1970  Compositional and Lexical Semantics in RoBERTa...
# 217  main.1996  Cold-Start and Interpretability: Turning Regul...
# ...

# %%
clean_df[clean_df['id'] == 'main.576']
# Out:
# Empty DataFrame
# Columns: [id, title, area, source, year, doi, abstract]
# Index: []

# %% [markdown]
# # Saving the results

# %%
previous_df = pd.read_csv('../data/cl_papers.csv', index_col=0)
previous_df
# Out:
#              id                                              title  \
# 0     main.1004  AnswerFact: Fact Checking in Product Question ...
# 1     main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2     main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3     main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4     main.1011  Knowledge Association with Hyperbolic Knowledg...
# ...         ...                                                ...
# 9250      T4773  Rank-Aware Negative Training for Semi-Supervis...
# 9251      T4777  Transparency Helps Reveal When Language Models...
# 9252      T4803  Design Choices for Crowdsourcing Implicit Disc...
# 9253      T4929        Time-and-Space-Efficient Weighted Deduction
# 9254      T5043  Collective Human Opinions in Semantic Textual ...
#
#                                                    area source  year  \
# 0                                    Question Answering  EMNLP  2020
# ...

# %%
# we'll delete previous rows from the conference
prev = previous_df[((previous_df['source'] == 'EMNLP') & (previous_df['year'] == 2020))]
prev[prev['area'] == 'Interpretability and Analysis of Models for NLP']
# Out:
#             id                                              title  \
# 14   main.1052  Asking without Telling: Exploring Latent Ontol...
# 43   main.1205  Top-Rank-Focused Adaptive Vote Collection for ...
# 62   main.1280  Pretrained Language Model Embryology: The Birt...
# 87   main.1428  Improving Low Compute Language Modeling with I...
# 119  main.1551  Pareto Probing: Trading Off Accuracy for Compl...
# 136  main.1612  Interpretation of NLP models through input mar...
# 137  main.1613  Learning Music Helps You Read: Using Transfer ...
# 138  main.1614  Generating Label Cohesive and Well-Formed Adve...
# 144  main.1626  Hate-Speech and Offensive Language Detection i...
# 145  main.1631  An Empirical Investigation Towards Efficient M...
# 197  main.1901        Are All Good Word Vector Spaces Isomorphic?
# 211  main.1970  Compositional and Lexical Semantics in RoBERTa...
# 217  main.1996  Cold-Start and Interpretability: Turning Regul...
# ...

# %%
# we'll delete previous rows from the conference
previous_df = previous_df[~((previous_df['source'] == 'EMNLP') & (previous_df['year'] == 2020))]
previous_df
# Out:
# Empty DataFrame
# Columns: [id, title, area, source, year, doi, abstract]
# Index: []

# %%
updated_df = pd.concat([previous_df, clean_df], ignore_index=True)
updated_df
# Out:
#             id                                              title  \
# 0    main.1004  AnswerFact: Fact Checking in Product Question ...
# 1    main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2    main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3    main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4    main.1011  Knowledge Association with Hyperbolic Knowledg...
# ..         ...                                                ...
# 776  TACL.2169                                     A* Beam Search
# 777  TACL.2221  Consistent Transcription and Translation of Sp...
# 778  TACL.2255  PERL: Pivot-based Domain Adaptation for Pre-tr...
# 779  TACL.2389  Improving Dialog Evaluation with a Multi-refer...
# 780  TACL.2411  Syntactic Structure Distillation Pretraining f...
#
#                                        area source  year  \
# 0                        Question Answering  EMNLP  2020
# ...

# %%
updated_df.to_csv('../data/cl_papers.csv')
