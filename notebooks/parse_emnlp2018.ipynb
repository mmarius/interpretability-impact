# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))

# %%
from utils import *

import pandas as pd
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
df = pd.read_csv('../data/emnlp2018/papers.csv')
df
# Out:
#                                                  Track Submission ID  \
# 0    Area A (Information Extraction and Question An...      587-TACL
# 1    Area A (Information Extraction and Question An...          1017
# 2    Area A (Information Extraction and Question An...          1989
# 3    Area A (Information Extraction and Question An...          2043
# 4    Area A (Information Extraction and Question An...          2134
# ..                                                 ...           ...
# 458                   Area H (Machine Learning) [LONG]           204
# 459                   Area H (Machine Learning) [LONG]          1198
# 460                   Area H (Machine Learning) [LONG]          1111
# 461                                        Area H or D     1379-TACL
# 462                                        Area H or D     1396-TACL
#
#                                       Submission Title  \
# 0    Joint Multitask Learning for Community Questio...
# 1    What Makes Reading Comprehension Questions Eas...
# 2    Commonsense for Generative Multi-Hop Question ...
# 3    Open Domain Question Answering Using Early Fus...
# 4    A Nil-Aware Answer Extraction Framework for Qu...
# ..                                                 ...
# 458  The importance of Being Recurrent for Modeling...
# 459  Towards Dynamic Computation Graphs via Sparse ...
# 460  Convolutional Neural Networks with Recurrent N...
# 461  Language Modeling for Morphologically Rich Lan...
# 462  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                                Authors
# 0         Shafiq Joty, Lluís Màrquez and Preslav Nakov
# 1    Saku Sugawara, Kentaro Inui, Satoshi Sekine an...
# 2            Lisa Bauer, Yicheng Wang and Mohit Bansal
# 3    Haitian Sun, Bhuwan Dhingra, Manzil Zaheer, Ka...
# 4                         Souvik Kundu and Hwee Tou Ng
# ..                                                 ...
# 458         Ke Tran, Arianna Bisazza and Christof Monz
# 459  Vlad Niculae, André F. T. Martins and Claire C...
# 460                                            Yi Yang
# 461  Daniela Gerz, Ivan Vulić, Edoardo Maria Ponti,...
# 462                     Aaron Jaech and Mari Ostendorf
#
# [463 rows x 4 columns]

# %%
set(df['Track']) # interpretabilty does not really have a track, maybe D?
# Out:
# {'Area A (Information Extraction and Question Answering) [LONG]',
#  'Area A from Area F (Discourse, Dialog, Summarization, Generation, Multimodal NLP) [LONG]',
#  'Area B (Text Mining and Information Retrieval) [LONG]',
#  'Area C (Social Media, Computational Social Science, Sentiment,  Opinion) [LONG]',
#  'Area D (Morphology, Syntax, Chunking, Psycholinguistics) [LONG]',
#  'Area E (Semantics) [LONG]',
#  'Area F (Discourse, Dialog, Summarization, Generation, Multimodal NLP) [LONG]',
#  'Area G (Machine Translation and Multilinguality) [LONG]',
#  'Area H (Machine Learning) [LONG]',
#  'Area H or D'}

# %%
new_df = pd.DataFrame()
new_df['id'] = df['Submission ID']
new_df['title'] = df['Submission Title']
new_df['area'] = df['Track']
new_df['interpretability'] = None
new_df['source'] = 'EMNLP2018'

new_df
# Out:
#             id                                              title  \
# 0     587-TACL  Joint Multitask Learning for Community Questio...
# 1         1017  What Makes Reading Comprehension Questions Eas...
# 2         1989  Commonsense for Generative Multi-Hop Question ...
# 3         2043  Open Domain Question Answering Using Early Fus...
# 4         2134  A Nil-Aware Answer Extraction Framework for Qu...
# ..         ...                                                ...
# 458        204  The importance of Being Recurrent for Modeling...
# 459       1198  Towards Dynamic Computation Graphs via Sparse ...
# 460       1111  Convolutional Neural Networks with Recurrent N...
# 461  1379-TACL  Language Modeling for Morphologically Rich Lan...
# 462  1396-TACL  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                                   area interpretability  \
# 0    Area A (Information Extraction and Question An...             None
# 1    Area A (Information Extraction and Question An...             None
# 2    Area A (Information Extraction and Question An...             None
# 3    Area A (Information Extraction and Question An...             None
# 4    Area A (Information Extraction and Question An...             None
# ..                                                 ...              ...
# 458                   Area H (Machine Learning) [LONG]             None
# 459                   Area H (Machine Learning) [LONG]             None
# 460                   Area H (Machine Learning) [LONG]             None
# 461                                        Area H or D             None
# 462                                        Area H or D             None
#
#         source
# 0    EMNLP2018
# 1    EMNLP2018
# 2    EMNLP2018
# 3    EMNLP2018
# 4    EMNLP2018
# ..         ...
# 458  EMNLP2018
# 459  EMNLP2018
# 460  EMNLP2018
# 461  EMNLP2018
# 462  EMNLP2018
#
# [463 rows x 5 columns]

# %%
new_df['doi'] = new_df['title'].apply(get_acl_anthology_doi)
new_df
# Out:
#             id                                              title  \
# 0     587-TACL  Joint Multitask Learning for Community Questio...
# 1         1017  What Makes Reading Comprehension Questions Eas...
# 2         1989  Commonsense for Generative Multi-Hop Question ...
# 3         2043  Open Domain Question Answering Using Early Fus...
# 4         2134  A Nil-Aware Answer Extraction Framework for Qu...
# ..         ...                                                ...
# 458        204  The importance of Being Recurrent for Modeling...
# 459       1198  Towards Dynamic Computation Graphs via Sparse ...
# 460       1111  Convolutional Neural Networks with Recurrent N...
# 461  1379-TACL  Language Modeling for Morphologically Rich Lan...
# 462  1396-TACL  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                                   area interpretability  \
# 0    Area A (Information Extraction and Question An...             None
# 1    Area A (Information Extraction and Question An...             None
# 2    Area A (Information Extraction and Question An...             None
# 3    Area A (Information Extraction and Question An...             None
# 4    Area A (Information Extraction and Question An...             None
# ..                                                 ...              ...
# 458                   Area H (Machine Learning) [LONG]             None
# 459                   Area H (Machine Learning) [LONG]             None
# 460                   Area H (Machine Learning) [LONG]             None
# 461                                        Area H or D             None
# 462                                        Area H or D             None
#
#         source                   doi
# 0    EMNLP2018  10.18653/v1/D18-1452
# 1    EMNLP2018  10.18653/v1/D18-1453
# 2    EMNLP2018  10.18653/v1/D18-1454
# 3    EMNLP2018  10.18653/v1/D18-1455
# 4    EMNLP2018  10.18653/v1/D18-1456
# ..         ...                   ...
# 458  EMNLP2018  10.18653/v1/D18-1503
# 459  EMNLP2018  10.18653/v1/D18-1108
# 460  EMNLP2018  10.18653/v1/D18-1109
# 461  EMNLP2018  10.1162/tacl_a_00032
# 462  EMNLP2018  10.1162/tacl_a_00035
#
# [463 rows x 6 columns]

# %%
previous_df = pd.read_csv('../data/parsed_data.csv')
previous_df = previous_df.drop('Unnamed: 0', axis=1)
previous_df
# Out:
#         id                                              title            area  \
# 0       21  Pre-training Multi-party Dialogue Models with ...  Virtual Poster
# 1       23  Dual-Gated Fusion with Prefix-Tuning for Multi...  Virtual Poster
# 2       25                Aerial Vision-and-Dialog Navigation  Virtual Poster
# 3       34  Fixing MoE Over-Fitting on Low-Resource Langua...  Virtual Poster
# 4       35  A Survey of Deep Learning for Mathematical Rea...         Posters
# ...    ...                                                ...             ...
# 2351   981  Orthographic Features for Bilingual Lexicon In...             NaN
# 2352  1227  Think Visually: Question Answering through Vir...             NaN
# 2353    22  Extracting Relational Facts by an End-to-End N...             NaN
# 2354   975  Neural Cross-Lingual Coreference Resolution An...             NaN
# 2355   972  Extracting Commonsense Properties from Embeddi...             NaN
#
#      interpretability                                doi   source
# 0                 NaN      10.18653/v1/2023.acl-long.533  ACL2023
# 1                 NaN  10.18653/v1/2023.findings-acl.572  ACL2023
# 2                 NaN  10.18653/v1/2023.findings-acl.190  ACL2023
# 3                 NaN  10.18653/v1/2023.findings-acl.897  ACL2023
# 4                 NaN      10.18653/v1/2023.acl-long.817  ACL2023
# ...               ...                                ...      ...
# 2351              NaN               10.18653/v1/P18-2062  ACL2019
# 2352              NaN               10.18653/v1/P18-1242  ACL2019
# 2353              NaN               10.18653/v1/P18-1047  ACL2019
# 2354              NaN               10.18653/v1/P18-2063  ACL2019
# 2355              NaN               10.18653/v1/P18-2102  ACL2019
#
# [2356 rows x 6 columns]

# %%
updated_df = pd.concat([previous_df, new_df], ignore_index=True)
updated_df
# Out:
#              id                                              title  \
# 0            21  Pre-training Multi-party Dialogue Models with ...
# 1            23  Dual-Gated Fusion with Prefix-Tuning for Multi...
# 2            25                Aerial Vision-and-Dialog Navigation
# 3            34  Fixing MoE Over-Fitting on Low-Resource Langua...
# 4            35  A Survey of Deep Learning for Mathematical Rea...
# ...         ...                                                ...
# 2814        204  The importance of Being Recurrent for Modeling...
# 2815       1198  Towards Dynamic Computation Graphs via Sparse ...
# 2816       1111  Convolutional Neural Networks with Recurrent N...
# 2817  1379-TACL  Language Modeling for Morphologically Rich Lan...
# 2818  1396-TACL  LOW-RANK RNN ADAPTATION FOR CONTEXT-AWARE LANG...
#
#                                   area interpretability  \
# 0                       Virtual Poster              NaN
# 1                       Virtual Poster              NaN
# 2                       Virtual Poster              NaN
# 3                       Virtual Poster              NaN
# 4                              Posters              NaN
# ...                                ...              ...
# 2814  Area H (Machine Learning) [LONG]             None
# 2815  Area H (Machine Learning) [LONG]             None
# 2816  Area H (Machine Learning) [LONG]             None
# 2817                       Area H or D             None
# 2818                       Area H or D             None
#
#                                     doi     source
# 0         10.18653/v1/2023.acl-long.533    ACL2023
# 1     10.18653/v1/2023.findings-acl.572    ACL2023
# 2     10.18653/v1/2023.findings-acl.190    ACL2023
# 3     10.18653/v1/2023.findings-acl.897    ACL2023
# 4         10.18653/v1/2023.acl-long.817    ACL2023
# ...                                 ...        ...
# 2814               10.18653/v1/D18-1503  EMNLP2018
# 2815               10.18653/v1/D18-1108  EMNLP2018
# 2816               10.18653/v1/D18-1109  EMNLP2018
# 2817               10.1162/tacl_a_00032  EMNLP2018
# 2818               10.1162/tacl_a_00035  EMNLP2018
#
# [2819 rows x 6 columns]

# %%
updated_df.to_csv('../data/parsed_data.csv')
